# %%
import pandas as pd
import numpy as np
import graphviz as vg
import random
import time
import datetime
import pickle
import sys
#!pip install git+git://github.com/pygraphviz/pygraphviz.git
print(sys.version)
# Out:
# 3.5.4 | packaged by conda-forge | (default, Aug 10 2017, 01:38:47) [MSC v.1900 64 bit (AMD64)]

# %%
def load(file_name):
    f =  open(file_name,'rb')
    b = pickle.load(f)
    return b
result = load("dicts")
resultdate = load("dictsdate1")
#resultdate2 = load("dictsdate2")
resultpeople1 = load("dictspeople1")
resultpeople2 = load("dictspeople2")
resultrank = load("dictspeople3")
resultlocation = load("dictslocation")
resultorg = load("dictsorg")
resultclass = load("dictsclass")

keysorg1 = list(result.keys())
keysorg2 = list(resultorg.keys())
keyspeople = list(resultpeople2.keys())
dates1 = resultdate1.values()
#dates2 = resltdate2.values()
ranks = list(resultrank.values())
locations = resultlocation.keys()

keyspeople

for i in range(len(resultpeople2)):
    resultpeople2[keyspeople[i]] = list(set(resultpeople2[keyspeople[i]]))
for i in range(len(resultrank)):
    resultrank[keyspeople[i]] = list(set(resultrank[keyspeople[i]]))
for i in range(len(resultorg)):
    resultorg[keysorg2[i]] = list(set(resultorg[keysorg2[i]]))
for i in range(len(resultclass)):
    if keysorg1[i] in resultclass.keys():
        resultclass[keysorg1[i]] = list(set(resultclass[keysorg1[i]]))
resultclass
# Out:
# {'African Union/United Nations Hybrid operation in Darfur': ['Peacekeeping'],
#  'Estación de Policía Ensenada (Policía Federal)': ['Policía Federal ; Policía'],
#  'Niger State Police Command': ['Police'],
#  'Estación de Policía Cruz de Elota (Policía Federal)': ['Policía Federal ; Policía'],
#  'Dobeli Police Station': ['Police'],
#  '2 Zona Militar': ['Ejército ; Militar'],
#  '15 Regimiento de Caballería Motorizado': ['Ejército ; Militar'],
#  'Barkin Ladi Police Division': ['Police'],
#  'Coordinación de Investigación de Gabinete Antidrogas (Policía Federal)': ['Policía Federal ; Policía'],
#  'Coordinación Estatal Queretaro (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Monclova (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Irapuato (Policía Federal)': ['Policía Federal ; Policía'],
#  'Madobi Police Division': ['Police'],
#  'Gowon Estate Police Division': ['Police'],
#  'Estación de Policía Matías Romero (Policía Federal)': ['Policía Federal ; Policía'],
#  'Subestación de Policía Mazamitla (Policía Federal)': ['Policía Federal ; Policía'],
#  'Mariri Police Division': ['Police'],
#  '222 Battalion': ['Army ; Military'],
#  'Bariga Police Division': ['Police'],
#  "No Man's Land Police Division": ['Police'],
#  '234 Special Operations Battalion': ['Army ; Military'],
#  'Unknown Police Area Command, Anambra State': ['Police'],
#  '66 Batallón de Infantería': ['Ejército ; Militar'],
#  'Hong Police Division': ['Police'],
#  'IX Región Militar': ['Ejército ; Militar'],
#  'Estación de Policía Nogales (Policía Federal)': ['Policía Federal ; Policía'],
#  'Operativo Semana Santa Segura 2015': ['Operación Conjunta ; Ejército ; Militar'],
#  '36 Batallón de Infantería': ['Ejército ; Militar'],
#  'Federal Capital Territory Command (State Security Service)': ['State Security Service (Internal Security)'],
#  '90 Batallón de Infantería ': ['Ejército ; Militar'],
#  '4 Zona Naval': ['Armada ; Militar'],
#  'Subestación de Policía Pirámides (Policía Federal)': ['Policía Federal ; Policía'],
#  '18 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  '73 Battalion': ['Army ; Military'],
#  'Subestación de Policía Zacualtipán (Policía Federal)': ['Policía Federal ; Policía'],
#  'Mubi Police Area Command': ['Police'],
#  'Omoku Police Division': ['Police'],
#  'Joint Task Force, Operation Restore Hope': ['Joint Task Force ; Military ; Army ; Police'],
#  'Operación Noreste': ['Operación Conjunta ; Ejército ; Militar'],
#  'Subestación de Policía Acaponeta (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ikotun Police Division': ['Police'],
#  '29 Batallón de Infantería': ['Ejército ; Militar'],
#  'Police Mobile Force Squadron 12': ['Police Mobile Force (Riot Police) ; Police'],
#  '4 Región Naval': ['Armada ; Militar'],
#  'Estación de Policía Tuxpan (Policía Federal)': ['Policía Federal ; Policía'],
#  '31 Zona Militar': ['Ejército ; Militar'],
#  'Estación de Policía Calpulalpan (Policía Federal)': ['Policía Federal ; Policía'],
#  'Umumba Police Division': ['Police'],
#  '35 Zona Militar': ['Ejército ; Militar'],
#  'Daura Police Division': ['Police'],
#  '23 Regimiento de Caballería Motorizado': ['Ejército ; Militar'],
#  'Badagry Police Division': ['Police'],
#  'Ibiono Ibom Police Division': ['Police'],
#  '6 Región Naval': ['Armada ; Militar'],
#  'Subestación de Policía Pijijiapan (Policía Federal)': ['Policía Federal ; Policía'],
#  '32 Zona Militar': ['Ejército ; Militar'],
#  'Primera Comandancia Regional (Uruapan, Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Estación de Policía Cárdenas (Policía Federal)': ['Policía Federal ; Policía'],
#  '43 Zona Militar': ['Ejército ; Militar'],
#  'Subestación de Policía Ixtlán del Río (Policía Federal)': ['Policía Federal ; Policía'],
#  'Yarakwa Police Division': ['Police'],
#  '1 Mechanised Division': ['Army ; Military'],
#  'Estación de Policía Izúcar de Matamoros (Policía Federal)': ['Policía Federal ; Policía'],
#  '46 Zona Militar': ['Ejército ; Militar'],
#  'Estación de Policía Pachuca (Policía Federal)': ['Policía Federal ; Policía'],
#  'Bakori Police Division': ['Police'],
#  'Coordinación Estatal Hidalgo (Policía Federal)': ['Policía Federal ; Policía'],
#  '30 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Subestación de Policía Guamúchil (Policía Federal)': ['Policía Federal ; Policía'],
#  '35 Artillery Brigade': ['Army ; Military'],
#  'Enugu Ezike Police Division': ['Police'],
#  '75 Strike Group': ['Air Force ; Military'],
#  '8 Región Naval': ['Armada ; Militar'],
#  '3 Basea Aérea Militar': ['Fuerza Aérea ; Militar'],
#  'Coordinación de Operaciones Especiales (Policía Federal)': ['Policía Federal ; Policía'],
#  '403 Electronic Maintenance Depot': ['Air Force ; Military'],
#  '91 Batallón de Infantería': ['Ejército ; Militar'],
#  'Ilashe Police Division': ['Police'],
#  'Police Mobile Force Squadron 28': ['Police Mobile Force (Riot Police) ; Police'],
#  '11 Regimiento de Caballería Motorizado': ['Ejército ; Militar'],
#  'Garin Alkali Police Division': ['Police'],
#  '7 Division Military Intelligence Brigade': ['Army ; Military'],
#  'Región Aérea del Noreste': ['Fuerza Aérea ; Militar'],
#  'Ebonyi State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Joint Task Force, Operation Restore Hope, Sector 2': ['Joint Task Force ; Military ; Army ; Police'],
#  '301 Artillery Regiment': ['Army ; Military'],
#  '10 Zona Militar': ['Ejército ; Militar'],
#  'Operación Tijuana 2010': ['Operación Conjunta ; Ejército ; Militar'],
#  '11 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Dirección General de Manejo de Crisis y Negociación (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Teziutlán (Policía Federal)': ['Policía Federal ; Policía'],
#  'Pen Cinema Police Division': ['Police'],
#  'Ogui Police Division': ['Police'],
#  'Ayobo Police Division': ['Police'],
#  'Dirección General de Operaciones (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ajah Police Division': ['Police'],
#  'Estación de Policía Ciudad Mante (Policía Federal)': ['Policía Federal ; Policía'],
#  'Policía Municipal de Chilpancingo de los Bravo': ['Policía Municipal ; Policía'],
#  '15 Batallón de Infantería': ['Ejército ; Militar'],
#  'Coordinación Estatal Quintana Roo (Policía Federal)': ['Policía Federal ; Policía'],
#  '14 Regimiento de Caballería Motorizada': ['Ejército ; Militar'],
#  'Police Mobile Force Squadron 19': ['Police Mobile Force (Riot Police) ; Police'],
#  'Nangere Police Division': ['Police'],
#  'Vunokilang Police Division': ['Police'],
#  'Estación de Policía Piedras Negras (Policía Federal)': ['Policía Federal ; Policía'],
#  'Uruan Police Division ': ['Police'],
#  'Estación de Policía Aeropuerto Mexicali (Policía Federal)': ['Policía Federal ; Policía'],
#  'Jimeta Police Division': ['Police'],
#  'Kaduna State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Dirección General de Equipos Especiales (Policía Federal)': ['Policía Federal ; Policía'],
#  '27 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Dopemu Police Division': ['Police'],
#  'Funtua Police Area Command': ['Police'],
#  'Estación de Policía Zacatepec (Policía Federal)': ['Policía Federal ; Policía'],
#  'Subestación de Policía Tamazunchale (Policía Federal)': ['Policía Federal ; Policía'],
#  'Doguwa Police Division': ['Police'],
#  'Estación de Policía Tierra Colorada (Policía Federal)': ['Policía Federal ; Policía'],
#  'Subestación de Policía Tempoal (Policía Federal)': ['Policía Federal ; Policía'],
#  '26 Zona Militar': ['Ejército ; Militar'],
#  'Ini Police Division': ['Police'],
#  'Police Mobile Force Squadron 29': ['Police Mobile Force (Riot Police) ; Police'],
#  'Operación Conjunta Culiacán-Navolato-Guamúchil-Mazatlán': ['Operación Conjunta ; Ejército ; Militar'],
#  'Logistics Command': ['Air Force ; Military'],
#  'Dirección Regional de Averiguaciones Previas (Morelia, Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Estación de Policía Acapulco (Policía Federal)': ['Policía Federal ; Policía'],
#  'Sumaila Police Division': ['Police'],
#  'Subestación de Policía Santa María del Río (Policía Federal)': ['Policía Federal ; Policía'],
#  'Rijiyar Zaki Police Division': ['Police'],
#  'Criminal Intelligence Bureau (Akwa Ibom State Police Command)': ['Police'],
#  'Tarkwa Bay Police Division': ['Police'],
#  'Estación de Policía Aeropuerto Internacional Tijuana (Policía Federal)': ['Policía Federal ; Policía'],
#  '38 Batallón de Infantería': ['Ejército ; Militar'],
#  'Gwale Police Division': ['Police'],
#  '73 Batallón de Infantería': ['Ejército ; Militar'],
#  'Operativo Conjunto Culiacán/Navolato': ['Operación Conjunta ; Ejército ; Militar'],
#  '242 Recce Battalion': ['Army ; Military'],
#  'Estación de Policía Puerto Vallarta (Policía Federal)': ['Policía Federal ; Policía'],
#  'Fiscalía Regional Uruapan (Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Unknown Brigade, 82 Division': ['Army ; Military'],
#  'Operation Lafiya Dole': ['Joint Task Force ; Military ; Army ; Police ; State Security Service (Internal Security)'],
#  'Dirección General de Traslados y Apoyo Penitenciario (Policía Federal)': ['Policía Federal ; Policía'],
#  'Coordinación Estatal Coahuila (Policía Federal)': ['Policía Federal ; Policía'],
#  'Policía Municipal de Acapulco de Juárez': ['Policía Municipal ; Policía'],
#  '14 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  '67 Batallón de Infantería': ['Ejército ; Militar'],
#  'Bayelsa State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Estación de Policía Aeropuerto Queretaro (Policía Federal)': ['Policía Federal ; Policía'],
#  'Zone 11 Police Command': ['Police'],
#  'Dirección General de Investigación de Delitos Federales (Policía Federal)': ['Policía Federal ; Policía'],
#  '1 Regimiento de Caballería Motorizada': ['Ejército ; Militar'],
#  'Operación Conjunta Chihuahua': ['Operación Conjunta ; Ejército ; Militar'],
#  'Estación de Policía Ciudad del Carmen (Policía Federal)': ['Policía Federal ; Policía'],
#  '61 Batallón de Infantería': ['Ejército ; Militar'],
#  'Coordinación Estatal Guanajuato (Policía Federal)': ['Policía Federal ; Policía'],
#  '79 Composite Group': ['Air Force ; Military'],
#  'Coordinación de Investigación Técnica y Operación (Policía Federal)': ['Policía Federal ; Policía'],
#  'Igando Police Division': ['Police'],
#  'Irede/Ikanre Police Division': ['Police'],
#  'Estación de Policía Iguala (Policía Federal)': ['Policía Federal ; Policía'],
#  'Hotoro Police Division': ['Police'],
#  'Otolo Police Division': ['Police'],
#  '14 Base Aérea Militar': ['Fuerza Aérea ; Militar'],
#  '23 Zona Militar': ['Ejército ; Militar'],
#  'Osolu Kingdom Police Division': ['Police'],
#  '7 Division': ['Army ; Military'],
#  '1 Battalion': ['Army ; Military'],
#  'Special Task Force, Sector 8': ['Joint Task Force ; Military ; Army ; Police'],
#  'United Nations Organization Stabilization Mission in the Democratic Republic of the Congo': ['Peacekeeping'],
#  'Unknown Police Division, Katsina State': ['Police'],
#  'Subprocuraduría Regional de Justicia de Morelia (Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  '13 Amphibious Brigade': ['Army ; Military'],
#  'Ganye Police Division': ['Police'],
#  '5 Zona Naval': ['Armada ; Militar'],
#  '27 Zona Militar': ['Ejército ; Militar'],
#  '13 Zona Militar': ['Ejército ; Militar'],
#  'Subestación de Policía La Cuchilla (Policía Federal)': ['Policía Federal ; Policía'],
#  'Sallari Police Division': ['Police'],
#  'Azuka Police Division': ['Police'],
#  '82 Division': ['Army ; Military'],
#  'Emene Police Division': ['Police'],
#  'Bassa Police Division': ['Police'],
#  'Oron Police Area Command': ['Police'],
#  '4 Zona Militar': ['Ejército ; Militar'],
#  'Amichi Police Division': ['Police'],
#  'Oturkpo Police Area Command': ['Police'],
#  'Primera Comandancia Regional (Zamora, Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Rumorji Police Division': ['Police'],
#  'Coordinación Estatal Nuevo León (Policía Federal)': ['Policía Federal ; Policía'],
#  'Iyana Ofa Police Station': ['Police'],
#  'Subestación de Policía Sombrerete (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ondo State Police Command': ['Police'],
#  'Presidencia Municipal de Acuña': ['Político'],
#  'Estación de Policía Zaragoza (Policía Federal)': ['Policía Federal ; Policía'],
#  'Agentes del Ministerio Público Adscritos al Supremo Tribunal de Justicia (Morelia, Michoacán) ': ['Policía Ministerial del Estado ; Policía'],
#  'Unknown Police Area Command, Nasarawa State': ['Police'],
#  'Rimi Police Division': ['Police'],
#  'State Criminal Investigation Department (Cross River State Police Command)': ['Police'],
#  'Central Police Station (Awka, Anambra State)': ['Police'],
#  'Etinan Police Division': ['Police'],
#  'Fuerza Naval del Golfo': ['Armada ; Militar'],
#  'Estación de Policía Villahermosa (Policía Federal)': ['Policía Federal ; Policía'],
#  'Nigerian Battalion 14 (UNIMIL)': ['Peacekeeping'],
#  'Isiokpo Police Division': ['Police'],
#  'Procuraduría General de Justicia (Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Civilian Joint Task Force, Sector 1': ['Civilian Joint Task Force (Irregulars)'],
#  'Estación de Policía Navojoa (Policía Federal)': ['Policía Federal ; Policía'],
#  'Imo State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Elere Police Division': ['Police'],
#  'Abagana Police Division': ['Police'],
#  'Operación Conjunta Nuevo León – Tamaulipas': ['Operación Conjunta ; Ejército ; Militar'],
#  'Coordinación Estatal Sinaloa (Policía Federal)': ['Policía Federal ; Policía'],
#  '28 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Dirección Regional de Control de Procesos (Lázaro Cárdenas, Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Coordinación de Investigación de Recursos de Procedencia Ilícita (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía San Roberto (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Chihuahua (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Oaxaca (Policía Federal)': ['Policía Federal ; Policía'],
#  'Escuadrón Aéreo 101': ['Fuerza Aérea ; Militar'],
#  '1 Basea Aérea Militar': ['Fuerza Aérea ; Militar'],
#  'United Nations Mission in Liberia': ['Peacekeeping'],
#  'Guards Brigade': ['Army ; Military'],
#  '22 Battalion': ['Army ; Military'],
#  'Akwa Ibom State Police Command': ['Police'],
#  'Unknown Police Area Command, Abia State': ['Police'],
#  'Subestación de Policía San Felipe (Policía Federal)': ['Policía Federal ; Policía'],
#  'Dirección Regional de Control de Procesos (Zitácuaro, Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Estación de Policía Aeropuerto Guadalajara (Policía Federal)': ['Policía Federal ; Policía'],
#  'Rejiyer/Remo Police Division': ['Police'],
#  "B' Police Division (Anambra State)": ['Police'],
#  'Operación Chihuahua': ['Operación Conjunta ; Fueras Especiales ; Ejército ; Militar'],
#  'Nnobi Police Division': ['Police'],
#  '7 Guards Battalion': ['Army ; Military'],
#  'Operation Restore Peace': ['Joint Task Force ; Army ; Military'],
#  'Gboko Police Area Commad': ['Police'],
#  'Danja Police Division': ['Police'],
#  'Subprocuraduría Regional de Justicia de Lázaro Cárdenas (Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Umuahia Police Area Command': ['Police'],
#  'Police Mobile Force Squadron 32': ['Police Mobile Force (Riot Police) ; Police'],
#  'Borno State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Lagos State Police Command': ['Police'],
#  '9 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Dirección General de Rescate y Apoyo a la Protección Civil (Policía Federal)': ['Policía Federal ; Policía'],
#  '33 Artillery Brigade': ['Army ; Military'],
#  'Song Police Division': ['Police'],
#  'Estación de Policía Ciudad Obregón (Policía Federal)': ['Policía Federal ; Policía'],
#  'Nigerian Army': ['Army ; Military'],
#  'Panshekara Police Division': ['Police'],
#  'Coordinación Estatal Baja California (Policía Federal)': ['Policía Federal ; Policía'],
#  '195 Battalion': ['Army ; Military'],
#  'Akwa Ibom State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  '17 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  '10 Regimiento de Caballería Motorizada': ['Ejército ; Militar'],
#  'Estación de Policía Aeropuerto Torreón (Policía Federal)': ['Policía Federal ; Policía'],
#  'Enugu State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Multinational Joint Task Force': ['Joint Task Force ; Army'],
#  'Police Mobile Force Squadron 24': ['Police Mobile Force (Riot Police) ; Police'],
#  'Dirección General de Operación Técnica Antidrogas (Policía Federal)': ['Policía Federal ; Policía'],
#  'Coordinación Estatal Guerrero (Policía Federal)': ['Policía Federal ; Policía'],
#  'Oke-Odo Police Division': ['Police'],
#  '25 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Ihala Police Division': ['Police'],
#  'Katsina State Police Command': ['Police'],
#  'Police Mobile Force Squadron 11': ['Police Mobile Force (Riot Police) ; Police'],
#  'Estación de Policía Aeropuerto Acapulco (Policía Federal)': ['Policía Federal ; Policía'],
#  'Woji Police Division': ['Police'],
#  'Operation BOYONA': ['Joint Task Force ; Military ; Army ; Police ; State Security Service (Internal Security)'],
#  'Policía Municipal de General Heliodoro Castillo': ['Policía Municipal ; Policía'],
#  'Police Mobile Force Squadron 47': ['Police Mobile Force (Riot Police) ; Police'],
#  '7 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Dirección General de Análisis Táctico (Policía Federal)': ['Policía Federal ; Policía'],
#  '12 Batallón de Infantería': ['Ejército ; Militar'],
#  'Subestación de Policía San Martín Texmelucan (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ochi Amichi Police Division': ['Police'],
#  'Ringim Police Division': ['Police'],
#  '48 Batallón de Infantería': ['Ejército ; Militar'],
#  '28 Batallón de Infantería': ['Ejército ; Militar'],
#  'Doubeli Police Division': ['Police'],
#  '9 Batallón de Infantería': ['Ejército ; Militar'],
#  '26 Task Force Brigade': ['Army ; Military'],
#  'Special Task Force, Sector 3': ['Joint Task Force ; Military ; Army ; Police'],
#  'Estación de Policía La Paz (Policía Federal)': ['Policía Federal ; Policía'],
#  'Dirección de Seguridad Pública (Abasolo, Coahuila)': ['Policía Municipal ; Policía'],
#  '22 Regimiento de Caballería Motorizado': ['Ejército ; Militar'],
#  '1 Zona Naval': ['Armada ; Militar'],
#  'Dirección General de Investigación de Delitos de Alto Impacto (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Aeropuerto Puebla (Policía Federal)': ['Policía Federal ; Policía'],
#  'Baure Police Division': ['Police'],
#  'Zone 10 Police Command': ['Police'],
#  '87 Batallón de Infantería': ['Ejército ; Militar'],
#  'VI Región Militar': ['Ejército ; Militar'],
#  'Estación de Policía Escárcega (Policía Federal)': ['Policía Federal ; Policía'],
#  '223 Armoured Battalion': ['Army ; Military'],
#  'Estación de Policía Aeropuerto San Luis Potosí (Policía Federal)': ['Policía Federal ; Policía'],
#  '56 Batallón de Infantería': ['Ejército ; Militar'],
#  'Ozubulu Police Division': ['Police'],
#  'Oluyole Police Station': ['Police'],
#  'Plateau State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  '12 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Edo State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Policía Municipal de Zihuatanejo de Azueta': ['Policía Municipal ; Policía'],
#  '40 Zona Militar': ['Ejército ; Militar'],
#  'Zone 6 Police Command': ['Police'],
#  'Subestación de Policía Cruz Grande (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ahoada Police Division': ['Police'],
#  'Isiokpo Police Station ': ['Police'],
#  '88 Batallón de Infantería': ['Ejército ; Militar'],
#  'Kwara State Police Command': ['Police'],
#  '445 NAF Hospital': ['Air Force ; Military'],
#  'Bayelsa State Police Command': ['Police'],
#  'Sokoto State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Police Mobile Force Squadron 46': ['Police Mobile Force (Riot Police) ; Police'],
#  'Bara Police Division': ['Police'],
#  'VIII Región Militar': ['Ejército ; Militar'],
#  'Estado Mayor Presidencial': ['Ejército ; Militar'],
#  'Unguwa Uku Police Division': ['Police'],
#  'Operation Sharan Daji': ['Joint Task Force ; Army ; Military'],
#  'Numan Police Division': ['Police'],
#  'Unknown Zonal Police Command': ['Police'],
#  '49 Batallón de Infantería': ['Ejército ; Militar'],
#  '2 Brigade Supply and Transport Company': ['Army ; Military'],
#  '14 Zona Naval': ['Armada ; Militar'],
#  'Estación de Policía Zacatecas (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ojoto Police Division': ['Police'],
#  'Coordinación de Investigación de Campo (Policía Federal)': ['Policía Federal ; Policía'],
#  '2 Brigade Medical Centre': ['Army ; Military'],
#  '18 Batallón de Infantería': ['Ejército ; Militar'],
#  'Subestación de Policía Cosamaloapan (Policía Federal)': ['Policía Federal ; Policía'],
#  '2 Batallón de Infantería': ['Ejército ; Militar'],
#  '12 Brigade': ['Army ; Military'],
#  '10 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Estación de Policía Aeropuerto Chetumal (Policía Federal)': ['Policía Federal ; Policía'],
#  'Mashi Police Division': ['Police'],
#  'Estación de Policía Durango (Policía Federal)': ['Policía Federal ; Policía'],
#  'Subestación de Policía Río Grande (Policía Federal)': ['Policía Federal ; Policía'],
#  'Central Police Station (Nnewi, Anambra State)': ['Police'],
#  'Iju Police Division (Lagos State)': ['Police'],
#  'Civilian Joint Task Force': ['Civilian Joint Task Force (Irregulars)'],
#  'Damagum Police Division': ['Police'],
#  '80 Batallón de Infantería': ['Ejército ; Militar'],
#  "D' Police Division (Benue State)": ['Police'],
#  '112 Task Force Battalion': ['Army ; Military'],
#  'Subestación de Policía Libres (Policía Federal)': ['Policía Federal ; Policía'],
#  'Jimeta Police Station': ['Police'],
#  '10 Basea Aérea Militar': ['Fuerza Aérea ; Militar'],
#  'Akwanga Police Division': ['Police'],
#  'Gwarzo Police Division': ['Police'],
#  'Ekiti State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Ogbor Hill Police Division': ['Police'],
#  'Coordinación Estatal Veracruz (Policía Federal)': ['Policía Federal ; Policía'],
#  'Shendam Police Division': ['Police'],
#  'Subestación de Policía Ciudad Isla (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Ometepec (Policía Federal)': ['Policía Federal ; Policía'],
#  'Subestación de Policía Xpujil (Policía Federal)': ['Policía Federal ; Policía'],
#  'Niger State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Dirección Regional de Averiguaciones Previas (Uruapan, Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  '3 Motorized Brigade': ['Army ; Military'],
#  'Estación de Policía Aguascalientes  (Policía Federal)': ['Policía Federal ; Policía'],
#  'Operación Interinstitucional Culiacán-Navolato-Guamúchil': ['Operación Conjunta; Fueras Especiales ; Ejército ; Militar'],
#  '3 Zona Naval': ['Armada ; Militar'],
#  "A' Police Division (Uyo, Akwa Ibom State) ": ['Police'],
#  '42 Batallón de Infantería': ['Ejército ; Militar'],
#  'Unknown Police Area Command, Adamawa State': ['Police'],
#  '69 Batallón de Infantería': ['Ejército ; Militar'],
#  'Ugwuaji Police Division': ['Police'],
#  'Estación de Policía Paso Morelos (Policía Federal)': ['Policía Federal ; Policía'],
#  'Ezinifite Police Division': ['Police'],
#  'Anambra State Police Command': ['Police'],
#  '18 Regimiento de Caballería Motorizado': ['Ejército ; Militar'],
#  'Unknown Brigade, 3 Armoured Division': ['Army ; Military'],
#  'Ogudu Police Division': ['Police'],
#  'Ogun State Police Command': ['Police'],
#  '76 Batallón de Infantería': ['Ejército ; Militar'],
#  'Mapo Police Station': ['Police'],
#  '12 Zona Naval': ['Armada ; Militar'],
#  'Policía Municipal de Iguala de la Independencia': ['Policía Municipal ; Policía'],
#  '29 Battalion': ['Army ; Military'],
#  'Zone 2 Police Command': ['Police'],
#  'Otop Abasi Area Command': ['Police'],
#  'Adamawa State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Elimgbu Police Division': ['Police'],
#  '13 Basea Aérea Militar': ['Fuerza Aérea ; Militar'],
#  '60 Batallón de Infantería': ['Ejército ; Militar'],
#  '8 Batallón de Infantería': ['Ejército ; Militar'],
#  'Estación de Policía Ciudad Victoria (Policía Federal)': ['Policía Federal ; Policía'],
#  'Dirección General de la Unidad Canina (Policía Federal)': ['Policía Federal ; Policía'],
#  'Subestación de Policía Ocosingo (Policía Federal)': ['Policía Federal ; Policía'],
#  'Police Mobile Force Squadron 54': ['Police Mobile Force (Riot Police) ; Police'],
#  'Policía Municipal de Petatlán': ['Policía Municipal ; Policía'],
#  'Osun State Police Command': ['Police'],
#  'Galadima Police Division': ['Police'],
#  'Coordinación de Investigación de Campo y Técnica Antidrogas (Policía Federal)': ['Policía Federal ; Policía'],
#  'Mile 1 Police Station': ['Police'],
#  'Estación de Policía Aeropuerto Mazatlán (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Aeropuerto Villahermosa (Policía Federal)': ['Policía Federal ; Policía'],
#  'Bunkure Police Division': ['Police'],
#  'Dawakin Kudu Police Division': ['Police'],
#  'Zone 4 Police Command': ['Police'],
#  'Musawa Police Division': ['Police'],
#  'Ikot Nakanda Police Division': ['Police'],
#  '32 Batallón de Infantería': ['Ejército ; Militar'],
#  'Kiyawa Police Division': ['Police'],
#  'Charanchi Police Division': ['Police'],
#  'Isheri Police Division': ['Police'],
#  'Estación de Policía Aeropuerto Ciudad Juárez (Policía Federal)': ['Policía Federal ; Policía'],
#  'Military Observer Group': ['Peacekeeping'],
#  '31 Batallón de Infantería': ['Ejército ; Militar'],
# ...
#  'División Científica (Policía Federal)': ['Policía Federal ; Policía'],
#  'Coordinación Estatal Durango (Policía Federal)': ['Policía Federal ; Policía'],
#  'Unknown Police Area Command, Jigawa State': ['Police'],
#  '405 Central Armament Depot': ['Air Force ; Military'],
#  'Ibesikpo Asutan Police Division': ['Police'],
#  'Bindawa Police Division': ['Police'],
#  'Achalla Police Division': ['Police'],
#  '22 Batallón de Infantería de Marina': ['Infantería de marina ; Armada ; Militar'],
#  'Onitsha Police Area Command': ['Police'],
#  'Subestación de Policía Atotonilco (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Tuxtla Gutiérrez (Policía Federal)': ['Policía Federal ; Policía'],
#  'Meiran Police Division': ['Police'],
#  'Benue State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  'Estación de Policía Autlán de Navarro (Policía Federal)': ['Policía Federal ; Policía'],
#  'Police Mobile Force Squadron 50': ['Police Mobile Force (Riot Police) ; Police'],
#  'Madagali Police Division': ['Police'],
#  'Unknown Brigade, 81 Division': ['Army ; Military'],
#  'Batagarawa Police Division': ['Police'],
#  'Asuntos Internos (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Tehuantepec (Policía Federal)': ['Policía Federal ; Policía'],
#  '9 Zona Militar': ['Ejército ; Militar'],
#  'Dirección General de Control Operativo (Policía Federal)': ['Policía Federal ; Policía'],
#  'X Región Militar': ['Ejército ; Militar'],
#  "A' Police Division (Yobe State)": ['Police'],
#  'Sheka Police Division': ['Police'],
#  'Estación de Policía Ciudad Juárez (Policía Federal)': ['Policía Federal ; Policía'],
#  'Isokoko Police Divsion': ['Police'],
#  '78 Batallón de Infantería': ['Ejército ; Militar'],
#  'Armed Forces of the Federal Republic of Nigeria': ['Army ; Navy; Air Force ; Military'],
#  'Gaya Police Division': ['Police'],
#  'Ukpor Police Division': ['Police'],
#  '28 Zona Militar': ['Ejército ; Militar'],
#  '20 Zona Militar': ['Ejército ; Militar'],
#  'Gombe State Command (State Security Service)': ['State Security Service (Internal Security)'],
#  '2 Brigade Provost Company': ['Army ; Military'],
#  'Estación de Policía San Andres Tuxtla (Policía Federal)': ['Policía Federal ; Policía'],
#  '25 Zona Militar': ['Ejército ; Militar'],
#  'Zaria Road Police Division (Kano State)': ['Police'],
#  '43 Batallón de Infantería': ['Ejército ; Militar'],
#  'Estación de Policía Gómez Palacio (Policía Federal)': ['Policía Federal ; Policía'],
#  '18 Basea Aérea Militar': ['Fuerza Aérea ; Militar'],
#  'Zamfara State Police Command': ['Police'],
#  'Nigerian Battalion 36 (UNMIL)': ['Peacekeeping'],
#  '1 Región Naval': ['Armada ; Militar'],
#  'Nzam Police Division': ['Police'],
#  '26 Battalion': ['Army ; Military'],
#  'Mani Police Division': ['Police'],
#  'Police Mobile Force': ['Police Mobile Force (Riot Police) ; Police'],
#  'Maroko Police Division': ['Police'],
#  '15 Zona Militar': ['Ejército ; Militar'],
#  '5 Región Naval': ['Armada ; Militar'],
#  'Estaciones de Policía Escobedo (Policía Federal)': ['Policía Federal ; Policía'],
#  'Estación de Policía Celaya (Policía Federal)': ['Policía Federal ; Policía'],
#  'Policía Municipal de Abasolo (Coahuila)': ['Policía Municipal ; Policía'],
#  'Farm Centre Police Division': ['Police'],
#  'Coordinación Estatal de la Policía Ministerial Investigadora (Michoacán)': ['Policía Ministerial del Estado ; Policía'],
#  'Department of Army Logistics': ['Army ; Military'],
#  '2 Región Naval': ['Armada ; Militar'],
#  'Igbologun Police Division': ['Police'],
#  '15 Basea Aérea Militar': ['Fuerza Aérea ; Militar'],
#  ...}

# %%
dot = vg.Graph()
dot.engine = 'dot'
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")
def areagraph1(area):
    alreadyedges = list()
    area = str(area)
    dot.node(area)
    dot.attr('node', shape='oval', style = "filled", fillcolor = "white", height = "0.02")
    if area not in resultpeople1.keys():
        print("This is not a valid entry. Here are valid entries.")
        print(list(set(resultpeople1.keys())))
        return -1
    for j in range(len(resultpeople1[area])):
        person = resultpeople1[area][j]
        rank = resultrank[person][0]
        if len(rank) > 1:
            for r in range(len(resultrank[person])):
                if r != 0:
                    rank = rank + ", " + resultrank[person][r]
                print(rank)
        if (str(person), str(area)) not in alreadyedges:
            alreadyedges.append((str(person), str(area)))
            dot.edge(str(person), str(area), color = "red", taillabel = rank, lblstyle="above, sloped")
        
        if area in keysorg:
            member = result[area]
            if len(member) == 0:
                member = ["No information about memberships."]
        else:
            member = ["No information about memberships."]
        if area in resultdate:
            dt = resultdate[area]
            if len(dt) == 0:
                dt3 = "No Date Given"
            else:
                dt1 = dt[len(dt)-1]
                dt2 = datetime.date(dt1.year, dt1.month, dt1.day)
                dt3 = str(dt2.strftime('%B %d, %Y'))
        else:
            dt3 = "N/A"
        for r in range(len(member)):
            if (str(area), str(member[r])) not in alreadyedges:
                alreadyedges.append((str(area), str(member[r])))
                dot.edge(str(area), str(member[r]), color = "green", headlabel = "Last Confirmed: " + dt3 + ".")
        if area in locations:
            location = resultlocation[area]
            if len(location) == 0:
                location = "No location given in data."
                if (str(area), str(location)) not in alreadyedges:
                    alreadyedges.append((str(area), str(location)))
                    dot.edge(str(area), str(location), color = "blue")
            else:
                location = location[0]
                if (str(area), str(location)) not in alreadyedges:
                    alreadyedges.append((str(area), str(location)))
                    dot.edge(str(area), str(location), color = "blue", headlabel = "Location:")
        else:
                location = "No location given in data."
                if (str(area), str(location)) not in alreadyedges:
                    alreadyedges.append((str(area), str(location)))
                    dot.edge(str(area), str(location), color = "blue")
    return dot
areagraph1("1 Mechanised Division")
dot.render('Graph1.jpg', view=True)
# Out:
# Commander
# Director of Engineering
# Director of Engineering, Commander
# Commander
# Commander
# Commander
# Commander
# Commander
# Commander
# Commander
# Commander
# Commander, Chief of Operations
# Commander
# Commander
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-44-708541944be9> in <module>()
#      62     return dot
#      63 areagraph1("1 Mechanised Division")
# ---> 64 dot.render('Graph1.jpg', view=True)
#
# C:\Users\thema_000\Anaconda3\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     169         filepath = self.save(filename, directory)
#     170
# --> 171         rendered = backend.render(self._engine, self._format, filepath)
#     172
#     173         if cleanup:
#
# C:\Users\thema_000\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     123     with open(os.devnull, 'w') as stderr:
#     124         try:
# --> 125             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     126         except OSError as e:
#     127             if e.errno == errno.ENOENT:
#
# C:\Users\thema_000\Anaconda3\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     269         if cmd is None:
#     270             cmd = popenargs[0]
# --> 271         raise CalledProcessError(retcode, cmd)
#     272     return 0
#     273
#
# CalledProcessError: Command '['dot.bat', '-Tpdf', '-O', 'Graph1.jpg']' returned non-zero exit status 1

# %%
dot = vg.Graph()
dot.engine = 'dot'
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")

def areagraph2(person):
    alreadyedges = list()
    person = str(person)
    dot.node(person)
    dot.attr('node', shape='oval', style = "filled", fillcolor = "white", height = "0.02")
    if person not in resultpeople2.keys():
        print("This is not a valid entry. Here are valid entries.")
        print(list(set(resultpeople2.keys())))
        return -1
    for j in range(len(resultpeople2[person])):
        area = resultpeople2[person][j]
        if (str(person), str(area)) not in alreadyedges:
            alreadyedges.append((str(person), str(area)))
            dot.edge(str(person), str(area), color = "red")
        personarea = resultpeople1[area]
        for r in range(len(personarea)):
            personarea1 = personarea[r]
        if (str(personarea1), str(area)) not in alreadyedges and (str(area), str(personarea1)) not in alreadyedges:
            alreadyedges.append((str(personarea1), str(area)))
            dot.edge(str(personarea1), str(area), color = "purple")
        if area in locations:
                location = resultlocation[area]
                if len(location) == 0:
                    location = "No location given in data."
                    if (str(area), str(location)) not in alreadyedges:
                        alreadyedges.append((str(area), str(location)))
                        dot.edge(str(area), str(location), color = "blue")
                    else:
                        location = location[0]
                        if (str(area), str(location)) not in alreadyedges:
                            alreadyedges.append((str(area), str(location)))
                            dot.edge(str(area), str(location), color = "blue", headlabel = "Location:")
                else:
                    location = "No location given in data."
                    if (str(area), str(location)) not in alreadyedges:
                        alreadyedges.append((str(area), str(location)))
                        dot.edge(str(area), str(location), color = "blue")
    return dot
areagraph2("Garba Ayodele Wahab")
dot.render('Graph2.jpg', view=True)
# Out:
# 'Graph2.jpg.pdf'

# %%
dot = vg.Graph()
dot.engine = 'dot'
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")

def areagraph3(org, color1):
    alreadyedges = list()
    org = str(org)
    dot.node(org)
    dot.attr('node', shape='oval', style = "filled", fillcolor = "white", height = "0.02")
    if org not in resultorg.keys():
        print("This is not a valid entry. Here are valid entries.")
        print(list(set(resultorg.keys())))
        return -1
    for j in range(len(resultorg[org])):
        area = resultorg[org][j]
        if (str(org), str(area)) not in alreadyedges:
            alreadyedges.append((str(org), str(area)))
            dot.edge(str(org), str(area), color = str(color1))
        class1 = resultclass[org]
    return dot

areagraph3("Operation BOYONA", "red")
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")
areagraph3("Operation Zaman Lafiya", "blue")
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")
areagraph3("Joint Task Force, Operation Restore Order I", "green")
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")
areagraph3("Operation Lafiya Dole", "purple")
dot.render('OperationOverlap', view=True)
# Out:
# 'OperationOverlap.pdf'
