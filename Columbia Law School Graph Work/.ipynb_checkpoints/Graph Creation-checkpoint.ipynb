# %%
import pandas as pd
import numpy as np
import graphviz as vg
import random
import time
import datetime
#!pip install --upgrade https://github.com/mikedewar/d3py/tarball/master
#!pip install osmapi 
import d3py
import pickle
#import osmapi

# %%
xls = pd.ExcelFile("SFMdata.xlsx")
xls1 = xls.parse(0)
xls2 = xls.parse(1)
xls3 = xls.parse(2)
xls1["Organization:ID"] = xls1.index
xls2["ID"] = xls2.index
xls1 = xls1.drop(['Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75'], 1)
xls2 = xls2.drop(['Unnamed: 35', 'Unnamed: 36'], 1)
newxls1 = pd.DataFrame()
for j in range (len(xls1)):
    if pd.notnull(xls1.iloc[j]["OrganizationMembership:member_id"]):
        row1 = xls1.iloc[j]
        row2 = pd.DataFrame(row1).T
        newxls1 = newxls1.append(row2, ignore_index = True)
newxls2 = pd.DataFrame()
for j in range (len(xls2)):
    if pd.notnull(xls2.iloc[j]["Organization"]):
        row1 = xls2.iloc[j]
        row2 = pd.DataFrame(row1).T
        newxls2 = newxls2.append(row2, ignore_index = True)

# %%
def load(file_name):
    f =  open(file_name,'r')
    b = pickle.load(f)
    return b
result = load("dicts")
resultdate = load("dictsdate")
resultpeople1 = load("dictspeople1")
resultpeople2 = load("dictspeople2")
resultrank = load("dictspeople3")
resultlocation = load("dictslocationtest")

keysorg = result.keys()
keyspeople = resultpeople2.keys()
dates1 = resultdate.values()
ranks = resultrank.values()
locations = resultlocation.keys()

for i in range(len(resultpeople2)):
    resultpeople2[keyspeople[i]] = list(set(resultpeople2[keyspeople[i]]))
for i in range(len(resultrank)):
    resultrank[keyspeople[i]] = list(set(resultrank[keyspeople[i]]))

# %%
result
# Out:
# {'22 Regimiento de Caballera Motorizado': [],
#  'Subestacin de Polica Ascensin (Polica Federal)': [],
#  'Estacin de Polica Nuevo Laredo (Polica Federal)': [],
#  'Bompai Police Division': [],
#  'Estacin de Polica Tuxtla Gutirrez (Polica Federal)': [],
#  'Gombi Police Division': [],
#  'Secretara de la Defensa Nacional': [],
#  'Subestacin de Polica San Martn Texmelucan (Polica Federal)': [],
#  '70 Batalln de Infantera': [],
#  'Regin Area del Noroeste': [],
#  'Gombe State Police Command': [],
#  'Multinational Joint Task Force': [],
#  '22 Compaa de Infantera No Encuadrada': [],
#  '19 Regimiento de Caballera Motorizada': [],
#  '76 Batalln de Infantera': ['Operacin Chihuahua'],
#  'Subestacin de Polica Martnez de la Torre (Polica Federal)': [],
#  '22 Batalln de Infantera de Marina': [],
#  'Katsina State Command (State Security Service)': [],
#  '6 Brigada de Infantera de Marina': [],
#  'Awkunanaw Police Division': [],
#  '34 Field Artillery Brigade': ['African Union/United Nations Hybrid operation in Darfur'],
#  'Presidencia Municipal de Abasolo (Coahuila)': [],
#  'African Union/United Nations Hybrid operation in Darfur': [],
#  'Operativo Conjunto Michoacn': [],
#  '28 Zona Militar': [],
#  'Estacin de Polica Aeropuerto Tapachula (Polica Federal)': [],
#  'Direccin General de Reaccin y Operacin (Polica Federal)': [],
#  'Zone 5 Police Command': [],
#  'Oworonsoki Police Division': [],
#  'Estacin de Polica Ciudad Mante (Polica Federal)': [],
#  'Panshekara Police Division': [],
#  'African Union Mission in the Sudan': [],
#  'Umumba Police Division': [],
#  'Fiscala Regional Zitcuaro (Michoacn)': [],
#  'Estacin de Polica Aeropuerto Tampico (Polica Federal)': [],
#  'Estacin de Polica Escrcega (Polica Federal)': [],
#  'Ukwa East Police Division': [],
#  '52 Batalln de Infantera': [],
#  'Ibese Police Division': [],
#  'Direccin General de Manejo de Crisis y Negociacin (Polica Federal)': [],
#  'Uli Police Division': [],
#  'Cross River State Police Command': [],
#  'Amechi-Uwani Police Division': [],
#  'Ogbomoso Police Area Command': [],
#  '5 Regin Naval': [],
#  'Subestacin de Polica Jiquilpan (Polica Federal)': [],
#  '17 Batalln de Infantera': [],
#  'Subestacin de Polica Palma Sola (Polica Federal)': [],
#  '22 Zona Militar': [],
#  'Subestacin de Polica Ro Grande (Polica Federal)': [],
#  'Subestacin de Polica Sabinas (Polica Federal)': [],
#  '42 Zona Militar': [],
#  'Estacin de Polica Taxco (Polica Federal)': [],
#  'Achalla Police Division': [],
#  'Zone 10 Police Command': [],
#  'Operacin Guerrero Seguro': [],
#  '1 Zona Militar': [],
#  'Uruan Police Division ': [],
#  'Direccin General de Anlisis Tctico Antidrogas (Polica Federal)': [],
#  'Estacin de Polica Torren (Polica Federal)': [],
#  'Estacin de Polica La Piedad (Polica Federal)': [],
#  'Ekiti State Command (State Security Service)': [],
#  'Subestacin de Polica Ojinaga (Polica Federal)': [],
#  'Direccin Regional de Control de Procesos (Zitcuaro, Michoacn)': [],
#  'Hong Police Division': [],
#  'Coordinacin Estatal Chihuahua (Polica Federal)': [],
#  'Estacin de Polica Texcoco (Polica Federal)': [],
#  '7 Division': ['Operation Lafiya Dole', 'Operation Zaman Lafiya'],
#  '2 Battalion': ['African Union/United Nations Hybrid operation in Darfur',
#   'Operation Sharan Daji',
#   'Special Task Force'],
#  'Coordinacin de Investigacin de Campo (Polica Federal)': [],
#  'Polica Municipal de Acapulco de Jurez': [],
#  'Estacin de Polica Aeropuerto Internacional Tijuana (Polica Federal)': [],
#  'Rivers State Command (State Security Service)': [],
#  'Sango Police Station': [],
#  'Subestacin de Polica Ixtapan de la Sal (Polica Federal)': [],
#  'Direccin General de Inteligencia Operativa (Polica Federal)': [],
#  'Gwagwarwa Police Division': [],
#  'Iyana Ofa Police Station': [],
#  '18 Batalln de Infantera ': [],
#  'Shuwa Police Division': [],
#  '25 Batalln de Infantera de Marina': [],
#  'Dopemu Police Division': [],
#  'Coordinacin de Reaccin y Alerta Inmediata (Polica Federal)': [],
#  'Central Police Station (Otukpo, Benue State)': [],
#  '15 Basea Area Militar': [],
#  'Subestacin el Salto Pueblo Nuevo (Polica Federal)': [],
#  '2 Batalln de Infantera de Marina': [],
#  'Coordinacin Estatal Jalisco (Polica Federal)': [],
#  'Fegge Police Division': [],
#  'Direccin General de Enlace y Cooperacin Interinstitucional (Polica Federal)': [],
#  'Estacin de Polica Los Mochis (Polica Federal)': [],
#  'Nsit Ubium Police Division': [],
#  'Ibiono Ibom Police Division': [],
#  'United Nations Organization Mission in Democratic Republic of the Congo': [],
#  'Eket Police Division': [],
#  '12 Cuerpo de Infantera de Defensas Rurales': ['Operacin Veracruz Seguro'],
#  'Zone 3 Police Command': [],
#  '11 Basea Area Militar': [],
#  'Unknown Brigade, 3 Armoured Division': [],
#  'Direccin General de Rescate y Apoyo a la Proteccin Civil (Polica Federal)': [],
#  'Subestacin de Polica San Rafael (Polica Federal)': [],
#  'Ojokoro Police Division': [],
#  'Estacin de Polica Cuautla (Polica Federal)': [],
#  'Nigeria Police Force': [],
#  'Operacin Veracruz Seguro': [],
#  'Ojoto Police Division': [],
#  'Estacin de Polica Aeropuerto Mexicali (Polica Federal)': [],
#  'Air Force Comprehensive School Ibadan': [],
#  'Estacin de Polica Lzaro Crdenas (Polica Federal)': [],
#  'Ihala Police Division': [],
#  'Secretara de Gobernacin': [],
#  'Otuocha Police Division': [],
#  "C' Police Division (Akwa Ibom State)": [],
#  '241 Recce Battalion': ['Multinational Joint Task Force'],
#  'Shendam Police Division': [],
#  'Ini Police Division': [],
#  'Estacin de Polica Poza Rica (Polica Federal)': [],
#  'Estacin de Polica Orizaba (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Puerto Vallarta (Polica Federal)': [],
#  '10 Zona Naval': [],
#  'Ahoada Police Division': [],
#  'Akim Police Area Command': [],
#  'Fika Police Division': [],
#  'Funtua Police Area Command': [],
#  '75 Batalln de Infantera': [],
#  'Nasarawa State Command (State Security Service)': [],
#  '6 Regin Naval': [],
#  'Estacin de Polica Ecatepec (Polica Federal)': [],
#  '8 Regin Naval': [],
#  'Estacin de Polica Chetumal (Polica Federal)': [],
#  'Estacin de Polica Zamora (Polica Federal)': [],
#  'Batagarawa Police Division': [],
#  'Polica Municipal de Coyuca de Bentez': [],
#  'Centro Tctico Operativo Tula (Polica Federal)': [],
#  'Polica Municipal de Atoyac de lvarez': [],
#  'Oron Police Area Command': [],
#  '18 Regimiento de Caballera Motorizado': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Langtang North Police Division': [],
#  'Estacin de Polica Morelia (Polica Federal)': [],
#  'Ilasan Police Division': [],
#  '13 Regimiento de Caballera Motorizado': [],
#  'Presidencia de la Repblica': [],
#  'Estacin de Polica Aeropuerto Cozumel (Polica Federal)': [],
#  'Anambra State Command (State Security Service)': [],
#  'Dunukofia Police Division': [],
#  '301 Artillery Regiment': ['African Union Mission in the Sudan',
#   'African Union Mission in the Sudan'],
#  '60 Batalln de Infantera': [],
#  'Zango Police Division': [],
#  'Nigerian Army': [],
#  'Gezawa Police Division': [],
#  '31 Field Artillery Brigade': ['Operation Sharan Daji', 'Special Task Force'],
#  'Ikotun Police Division': [],
#  'Estacin de Polica Tecamachalco (Polica Federal)': [],
#  'Dutsi Police Division': [],
#  '8 Basea Area Militar': [],
#  "Mai'Adua Police Division": [],
#  'Coordinacin Regional Noreste (Polica Federal)': [],
#  'Estacin de Polica Queretaro (Polica Federal)': [],
#  'Estacin de Polica Jimnez (Polica Federal)': [],
#  '2 Zona Naval': [],
#  'Estacin de Polica Toluca (Polica Federal)': [],
#  'Ndiegoro Police Division': [],
#  'Estacin de Polica Ciudad Obregn (Polica Federal)': [],
#  '2 Regin Naval': [],
#  'Operation Restore Peace': [],
#  '30 Zona Militar': [],
#  'Subestacin de Polica Ocosingo (Polica Federal)': [],
#  'Taura Police Division': [],
#  '405 Central Armament Depot': [],
#  'Abagana Police Division': [],
#  'Ukpor Police Division': [],
#  'Criminal Intelligence Bureau (Anambra State Police Command)': [],
#  'Direccin General de Intervencin (Polica Federal)': [],
#  '31 Zona Militar': [],
#  'Badagry Police Division': [],
#  'Unknown Police Area Command, Jigawa State': [],
#  'Estacin de Polica San Cristbal (Polica Federal)': [],
#  'Unknown Zonal Police Command': [],
#  'Air Force Secondary School Ikeja': [],
#  'New Haven Police Division': [],
#  '58 Batalln de Infantera': [],
#  'Nsukka Police Area Command': [],
#  'Ipaja Police Division': [],
#  'Estacin de Polica Reynosa (Polica Federal)': [],
#  'Estacin de Polica Nochixtln (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Culiacn (Polica Federal)': [],
#  'Coordinacin de Investigacin de Gabinete Antidrogas (Polica Federal)': [],
#  '8 Regimiento Mecanizado': ['Operacin Chihuahua'],
#  'Rumupakni Police Division': [],
#  '21 Armoured Brigade Garrison': [],
#  '6 Regimiento de Caballera Motorizado': [],
#  'Nsit Attai Police Division': [],
#  '66 Batalln de Infantera': ['Operacin Chihuahua'],
#  'Primera Comandancia Regional (Morelia, Michoacn)': [],
#  'Gano Police Division': [],
#  'Batsari Police Division': [],
#  'K/Fada Police Division': [],
#  '47 Batalln de Infantera': [],
#  'Ogun State Police Command': [],
#  'Abak Police Division': [],
#  'Birnin Kudu Police Division': [],
#  'Ohanze Police Division': [],
#  'Estacin de Polica Len (Polica Federal)': [],
#  'Direccin General de Anlisis Tctico (Polica Federal)': [],
#  '98 Batalln de Infantera': ['Operacin Conjunta Chihuahua'],
#  'Estado Mayor de la Defensa Nacional': [],
#  'Elimgbu Police Division': [],
#  'Estacin de Polica Aeropuerto Queretaro (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Len Bajo (Polica Federal)': [],
#  'Subestacin de Polica Ozulama (Polica Federal)': [],
#  'Department of Operations': [],
#  'Kano State Police Command': [],
#  '93 Battalion': ['Joint Task Force, Operation Restore Hope',
#   'Joint Task Force, Operation Restore Order I'],
#  '10 Basea Area Militar': [],
#  'Direccin General de Investigacin de Delitos contra la Seguridad e Integridad de las Personas (Polica Federal)': [],
#  '3 Batalln de Infantera': [],
#  'Zone 6 Police Command': [],
#  'Logistics Command': [],
#  'Zamfara State Command (State Security Service)': [],
#  'Bassa Police Division': [],
#  'Ijanikin Police Division': [],
#  '12 Regimiento de Caballera Motorizado': [],
#  'Osolu Kingdom Police Division': [],
#  'Estacin de Polica Ciudad Valles (Polica Federal)': [],
#  'Oyigbo Police Division': [],
#  'Bayelsa State Police Command': [],
#  'Subestacin de Polica Cananea (Polica Federal)': [],
#  'Mubi Police Area Command': [],
#  'Kebbi State Police Command': [],
#  'Eleme Police Division': [],
#  'Pen Cinema Police Division': [],
#  '45 Batalln de Infantera': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Mariri Police Division': [],
#  'Estacin de Polica Aeropuerto La Paz (Polica Federal)': [],
#  '17 Basea Area Militar': [],
#  'Estacin de Polica Zaragoza (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Acapulco (Polica Federal)': [],
#  '30 Batalln de Infantera de Marina': [],
#  '50 Batalln de Infantera': [],
#  '36 Zona Militar': [],
#  'Dawakin Kudu Police Division': [],
#  'Iyaganku Police Division': [],
#  'Unknown Brigade, 1 Mechanised Division': [],
#  "A' Police Division (Yobe State)": [],
#  'Estacin de Polica Colima (Polica Federal)': [],
#  'Estacin de Polica Cruz de Elota (Polica Federal)': [],
#  'Unknown Police Area Command, Benue State': [],
#  '445 NAF Hospital': [],
#  'Kogi State Police Command': [],
#  'Onipanu Police Division (Lagos State)': [],
#  'Subestacin de Polica La Ceiba (Polica Federal)': [],
#  'Ohuru Isimiri Police Division': [],
#  'Igbo-Etiti Police Division': [],
#  'Zone 7 Police Command': [],
#  '73 Battalion': ['African Union/United Nations Hybrid operation in Darfur',
#   'Joint Task Force, Operation Restore Hope',
#   'Multinational Joint Task Force'],
#  '55 Batalln de Infantera': [],
#  'Subestacin de Polica Mazamitla (Polica Federal)': [],
#  'Odukpani Police Division': [],
#  'Delta State Police Command': [],
#  'Subestacin de Polica Comalapa (Polica Federal)': [],
#  'Madobi Police Division': [],
#  'Ahoada Police Area Command': [],
#  'Zaria Road Police Division (Kano State)': [],
#  'Atakpa Police Division': [],
#  'Uratta-Eziukwu Police Division': [],
#  'Laranto Police Division': [],
#  'Direccin General de Explosivos (Polica Federal)': [],
#  '84 Batalln de Infantera': [],
#  '1 Mechanised Division': ['Operation BOYONA', 'Operation Sharan Daji'],
#  'Buni Yadi Police Division': [],
#  'Estacin de Polica Tierra Colorada (Polica Federal)': [],
#  '57 Batalln de Infantera': [],
#  'Unknown Police Area Command, Anambra State': [],
#  'Estacin de Polica Serdn (Polica Federal)': [],
#  'Nigerian Air Force Headquarters': [],
#  '64 Batalln de Infantera': [],
#  'Ubakala Police Division': [],
#  '15 Batalln de Infantera': ['Operacin Conjunta Nuevo Len  Tamaulipas',
#   'Operacin Conjunta Nuevo Len  Tamaulipas',
#   'Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Aguata Police Division': [],
#  'Plateau State Command (State Security Service)': [],
#  '2 Mechanised Division': ['Operation BOYONA',
#   'Operation BOYONA',
#   'Operation BOYONA'],
#  'Sokoto State Command (State Security Service)': [],
#  'Subestacin de Polica Tamazunchale (Polica Federal)': [],
#  'Farm Centre Police Division': [],
#  '3 Zona Militar': [],
#  'Estacin de Polica Coatzacoalcos (Polica Federal)': [],
#  'Unknown Police Area Command, Plateau State': [],
#  'Subestacin de Polica Tula de Allende (Polica Federal)': [],
#  'Coordinacin Estatal Veracruz (Polica Federal)': [],
#  'Polica Municipal de Zihuatanejo de Azueta': [],
#  'Dumne Police Division': [],
#  'Anambra State Police Command': [],
#  'Coordinacin Regional Noroeste (Polica Federal)': [],
#  'Unknown Police Area Command, Cross River State': [],
#  '32 Zona Militar': [],
#  'Agugu Police Station': [],
#  'Police Mobile Force Squadron 49': [],
#  'Police Mobile Force Squadron 48': [],
#  'Police Mobile Force Squadron 47': [],
#  'Police Mobile Force Squadron 46': [],
#  'Police Mobile Force Squadron 45': ['Special Task Force'],
#  'Police Mobile Force Squadron 44': ['Special Task Force'],
#  'Police Mobile Force Squadron 43': [],
#  '91 Batalln de Infantera': [],
#  'Police Mobile Force Squadron 41': [],
#  'Police Mobile Force Squadron 40': [],
#  '407 Equipment Supply Depot': [],
#  'Zamfara State Police Command': [],
#  'Mayo Belwa Police Division': [],
#  'Obosi Police Division': [],
#  'Mani Police Division': [],
#  'Sumaila Police Division': [],
#  'Awgu Police Division': [],
#  '1 Regimiento de Caballera Motorizada': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Agugu Police Division': [],
#  'Shomolu Police Division': [],
#  '1 Regimiento de Caballera Motorizado': [],
#  'State Criminal Investigation Department (Cross River State Police Command)': [],
#  'Angwan-Rogo Police Division': [],
#  'Potiskum Police Area Command': [],
#  '15 Regimiento de Caballera Motorizado': [],
#  'Fagge Police Division': [],
#  '1 Batalln de Infantera de Marina': [],
#  '7 Batalln de Infantera de Marina': [],
#  'Estacin de Polica Tecpn de Galeana (Polica Federal)': [],
#  'Coordinacin de Investigacin Tcnica y Operacin (Polica Federal)': [],
#  'Direccin Regional de Control de Procesos (Uruapan, Michoacn)': [],
#  'Subestacin de Polica Vista Hermosa (Polica Federal)': [],
#  'Estacin de Polica Tampico (Polica Federal)': [],
#  "Area 'J' Police Area Command (Lagos State)": [],
#  'Subestacin de Polica lamo (Polica Federal)': [],
#  '41 Zona Militar': [],
#  'Ekiti State Police Command': [],
#  'Shguwa Police Division': [],
#  'Demsa Police Division': [],
#  '176 Special Forces Guards Battalion': [],
#  '59 Batalln de Infantera': [],
#  '2 Regimiento de Caballera Motorizado': ['Operacin Tijuana 2010'],
#  'Estacin de Polica La Tinaja (Polica Federal)': [],
#  'Dambatta Police Division': [],
#  '73 Batalln de Infantera': [],
#  '23 Armoured Brigade': ['African Union Mission in the Sudan',
#   'Operation Lafiya Dole'],
#  'Direccin General de Anlisis Tctico de Delitos contra el Sistema Financiero (Polica Federal)': [],
#  '88 Batalln de Infantera': [],
#  'Direccin General de Personal (Polica Federal)': [],
#  '12 Batalln de Infantera': [],
#  'Lala Police Station': [],
#  'Subprocuradura Regional de Justicia de Lzaro Crdenas (Michoacn)': [],
#  'Armed Forces of the Federal Republic of Nigeria': [],
#  '242 Recce Battalion': ['Operation Lafiya Dole',
#   'United Nations Mission in Liberia'],
#  '31 Batalln de Infantera ': [],
#  '26 Zona Militar': ['Operacin Veracruz Seguro'],
#  '7 Batalln de Infantera': ['Mando Especial de la Huasteca'],
#  '8 Batalln de Infantera': ['Operativo Semana Santa Segura 2015'],
#  '28 Batalln de Infantera': [],
#  'Operacin Tijuana 2010': [],
#  'Federal Capital Territory Command (State Security Service)': [],
#  '1 Basea Area Militar': [],
#  'Eastern Ngwa Police Division': [],
#  '29 Battalion': ['African Union Mission in the Sudan',
#   'African Union/United Nations Hybrid operation in Darfur',
#   'Joint Task Force, Operation Pulo Shield, Sector 2'],
#  'Estacin de Polica Aeropuerto Ciudad de Mxico (Polica Federal)': [],
#  'Eziama Police Division': [],
#  '4 Zona Militar': [],
#  '15 Zona Militar': [],
#  'Ezinifite Police Division': [],
#  '3 Armoured Division Garrison': [],
#  'Subestacin de Polica Ixtln del Ro (Polica Federal)': [],
#  '11 Zona Naval': [],
#  'Ariaria Police Division': [],
#  'Direccin General de Fichas y Registros Delictivos (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Manzanillo (Polica Federal)': [],
#  'Unguwa Uku Police Division': [],
#  "A' Police Division (Uyo, Akwa Ibom State) ": [],
#  'Borokiri Police Division': [],
#  'Coordinacin Estatal Yucatn (Polica Federal)': [],
#  'Coordinacin Estatal Quintana Roo (Polica Federal)': [],
#  '5 Zona Naval': [],
#  "B' Police Division (Benue State)": [],
#  'Estacin de Polica Chihuahua (Polica Federal)': [],
#  '40 Zona Militar': [],
#  'Estacin de Polica Aeropuerto Monterrey (Polica Federal)': [],
#  '541 Brigade Signals': [],
#  'Estacin de Polica Hidalgo del Parral (Polica Federal)': [],
#  'Hockey Centre Police Division': [],
#  'Subestacin de Polica Tecate (Polica Federal)': [],
#  '61 Batalln de Infantera': [],
#  'Direccin General de Investigacin de Delitos Federales (Polica Federal)': [],
#  'Sabon Garin Daura Police Station': [],
#  '11 Batalln de Infantera de Marina': [],
#  'Woji Police Division': [],
#  'Force Headquarters': [],
#  'Subestacin de Polica Gonzlez (Polica Federal)': [],
#  'Guards Brigade': [],
#  'Estacin de Polica Linares (Polica Federal)': [],
#  'Imo State Police Command': [],
#  'Coordinacin Estatal Zacatecas (Polica Federal)': [],
#  'Estacin de Polica Lagos de Moreno (Polica Federal)': [],
#  '14 Basea Area Militar': [],
#  'Unknown Police Area Command, Enugu State': [],
#  'Subestacin de Polica Sabinas Hidalgo (Polica Federal)': [],
#  'Eastern Obolo Police Division': [],
#  'Epe Police Division': [],
#  'Minjibir Police Division': [],
#  'Police Mobile Force Squadron 54': [],
#  'Direccin General de Apoyo Tctico contra Narcotrfico y Delitos Conexos (Polica Federal)': [],
#  'Police Mobile Force Squadron 50': [],
#  '13 Zona Militar': [],
#  'Police Mobile Force Squadron 52': [],
#  'Police Mobile Force Squadron 53': [],
#  'Nassarawa Police Division': [],
#  'Lagos State Police Command': [],
#  'Estacin de Polica Tehuacn (Polica Federal)': [],
#  'Direccin General de Inteligencia Financiera para la Prevencin (Polica Federal)': [],
#  'Barkin Ladi Police Division': [],
#  '15 Batalln de Infantera de Marina': [],
#  'Subestacin de Polica Constitucin (Polica Federal)': [],
#  'Unknown Brigade, 7 Division': [],
#  'Yola Police Area Command': [],
#  'Central Police Station (Umuahia, Abia State)': [],
#  'Unknown Nigerian Army Division': [],
#  '4 Mechanized Brigade': ['Joint Task Force, Operation Pulo Shield, Sector 1'],
#  'Subestacin de Polica Acmbaro (Polica Federal)': [],
#  'Subestacin de Polica Ciudad Isla (Polica Federal)': [],
#  '322 Artillery Regiment': ['African Union/United Nations Hybrid operation in Darfur',
#   'Nigerian Battalion 41 (UNAMID)',
#   'Operation BOYONA',
#   'Operation Zaman Lafiya',
#   'United Nations Mission in Liberia'],
#  '32 Artillery Brigade Garrison': [],
#  'Operation Lafiya Dole': [],
#  '39 Zona Militar': [],
#  '16 Batalln de Infantera de Marina': [],
#  'Police Mobile Force Squadron 34': [],
#  'V Regin Militar': [],
#  'Estacin de Polica Crdenas (Polica Federal)': [],
#  'Subestacin de Polica Soto La Marina (Polica Federal)': [],
#  'Coordinacin Estatal Puebla (Polica Federal)': [],
#  'Imo State Command (State Security Service)': [],
#  'Estacin de Polica Pachuca (Polica Federal)': [],
#  'Osisioma Police Station': [],
#  'Abayi Police Division': [],
#  '6 Batalln de Infantera': [],
#  'Criminal Intelligence Bureau (Adamawa State Police Command)': [],
#  'Naibawa Police Division': ['Joint Task Force, Kano State'],
#  'Estacin de Polica Tulancingo (Polica Federal)': [],
#  'Operation Zaman Lafiya': [],
#  'Direccin General de Equipos Especiales (Polica Federal)': [],
#  'Subestacin de Polica Sombrerete (Polica Federal)': [],
#  '20 Zona Militar': [],
#  'Zone 9 Police Command': [],
#  'Alade Police Division': [],
#  'Coordinacin Estatal Colima (Polica Federal)': [],
#  'Estacin de Polica Matamoros (Polica Federal)': [],
#  'Zone 12 Police Command': [],
#  'Delta State Command (State Security Service)': [],
#  'Akwa Ibom State Command (State Security Service)': [],
#  '18 Batalln de Infantera de Marina': [],
#  'Direccin General de Investigacin de Delitos de Alto Impacto (Polica Federal)': [],
#  'Estacin de Polica Izcar de Matamoros (Polica Federal)': [],
#  'Estacin de Polica Zinacantepec (Polica Federal)': [],
#  'Subestacin de Polica Tuxtepec (Polica Federal)': [],
#  'Doguwa Police Division': [],
#  '13 Batalln de Infantera de Marina': [],
#  '2 Brigade Medical Centre': [],
#  'Subestacin de Polica Xpujil (Polica Federal)': [],
#  'Estacin de Polica Palenque (Polica Federal)': [],
#  'United Nations Mission in Liberia': [],
#  'Subestacin de Polica Petacalco (Polica Federal)': [],
#  'Estacin de Polica Manzanillo (Polica Federal)': [],
#  'Zone 2 Police Command': [],
#  'Tarkwa Bay Police Division': [],
#  'Polica Federal': [],
#  'Estacin de Polica Tapachula (Polica Federal)': [],
#  'Federal Housing Police Division': [],
#  'Zone 11 Police Command': [],
#  '82 Batalln de Infantera': [],
#  '195 Battalion': ['Joint Task Force, Operation Pulo Shield, Sector 1',
#   'Joint Task Force, Operation Pulo Shield, Sector 1',
#   'United Nations Mission in Liberia',
#   'United Nations Mission in Liberia'],
#  'Subestacin de Polica Magdalena (Polica Federal)': [],
#  'Tactical Air Command': [],
#  'Police Mobile Force Squadron 42': [],
#  'Subestacin de Polica Jalpa (Polica Federal)': [],
#  '1 Brigada de Infantera de Marina': [],
#  '3 Brigada de Infantera de Marina': [],
#  'Police Mobile Force': [],
#  'Estacin de Polica Aeropuerto Hermosillo (Polica Federal)': [],
#  'Subestacin de Polica Madre Vieja (Polica Federal)': [],
#  '23 Zona Militar': [],
#  '112 Task Force Battalion': ['Operation Lafiya Dole'],
#  'Asuntos Internos (Polica Federal)': [],
#  '92 Batalln de Infantera ': [],
#  'Subprocuradura Regional de Justicia de Apatzingn (Michoacn)': [],
#  'Estacin de Polica Puerto Escondido (Polica Federal)': [],
#  'Estacin de Polica Ciudad Victoria (Polica Federal)': [],
#  'Kano State Command (State Security Service)': [],
#  'Jimeta Police Division': [],
#  '103 Battalion': ['African Union Mission in the Sudan',
#   'African Union/United Nations Hybrid operation in Darfur',
#   'Operation Lafiya Dole',
#   'Operation Zaman Lafiya',
#   'United Nations Mission in Liberia'],
#  'Special Task Force, Sector 6': [],
#  'Polica Municipal de Acua (Coahuila)': [],
#  '323 Artillery Regiment': ['African Union Mission in the Sudan',
#   'United Nations Mission in Liberia'],
#  '25 Zona Militar': [],
#  '223 Armoured Battalion': ['African Union/United Nations Hybrid operation in Darfur',
#   'Operation Restore Peace',
#   'United Nations Mission in Liberia'],
#  'Garin Alkali Police Division': [],
#  "C' Police Division (Plateau State)": [],
#  'Ogun State Command (State Security Service)': [],
#  '26 Battalion': ['African Union/United Nations Hybrid operation in Darfur',
#   'Military Observer Group',
#   'Operation Restore Peace',
#   'United Nations Mission in Sierra Leone'],
#  '21 Batalln de Infantera': [],
#  'Direccin General de Operaciones Tcnicas (Polica Federal)': [],
#  'Federal Capital Territory Police Command': [],
#  'Special Area Police Division': [],
#  'Unknown Police Division, Abia State': [],
#  'Military Observer Group': [],
#  'Ukanafun Police Division': [],
#  '5 Brigada de Infantera de Marina': [],
#  '12 Zona Militar': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Estacin de Polica Matas Romero (Polica Federal)': [],
#  'Subestacin de Polica Ciudad Acua (Polica Federal)': [],
#  'Estacin de Polica Cuautitln Izcali (Polica Federal)': [],
#  'Subestacin de Polica Maravatio (Polica Federal)': [],
#  'Abattoir Police Division': [],
#  'Guards Brigade Garrison': [],
#  '88 Batalln de Infantera ': [],
#  '14 Regimiento de Caballera Motorizada': ['Operacin Noreste'],
#  'Ikot Edim Police Division': [],
#  'Wamba Police Division': [],
#  '21 Batalln de Infantera de Marina': [],
#  'Borokiri Police Station': [],
#  'Estacin de Polica Aeropuerto Torren (Polica Federal)': [],
#  '30 Batalln de Infantera': [],
#  "E' Police Division (Benue State)": [],
#  'Zone 1 Police Command': [],
#  '3 Battalion': ['Joint Task Force, Operation Pulo Shield, Sector 1',
#   'Joint Task Force, Operation Restore Hope',
#   'Operation Lafiya Dole'],
#  'Estacin de Polica Tepic (Polica Federal)': [],
#  'Faskari Police Division': [],
#  'Subestacin de Polica Guamchil (Polica Federal)': [],
#  'Coordinacin Estatal Sinaloa (Polica Federal)': [],
#  'Emene Police Division': [],
#  'Potiskum Police Division': [],
#  '38 Zona Militar': [],
#  'Unknown Police Area Command, Katsina State': [],
#  "Area 'M' Police Area Command (Lagos State)": [],
#  'Dustin-ma Police Division': [],
#  '1 Division Internal Security Force': [],
#  'Abia State Police Command': [],
#  'Yarakwa Police Division': [],
#  '21 Armoured Brigade': ['African Union Mission in the Sudan',
#   'Operation Lafiya Dole'],
#  'Central Police Station (Onitsha, Anambra State) ': [],
#  'Operacin Chihuahua': [],
#  'Awka Police Area Command': [],
#  'Estacin de Polica Tlalpan (Polica Federal)': [],
#  'Bakori Police Division': [],
#  '45 Zona Militar': [],
#  'Coordinacin de Investigacin de Recursos de Procedencia Ilcita (Polica Federal)': [],
#  'Uzo-Uwani Police Division': [],
#  'Divisin de Seguridad Regional (Polica Federal)': [],
#  'Subestacin de Polica Yuriria (Polica Federal)': [],
#  'Procuradura General de Justicia (Michoacn)': [],
#  '90 Batalln de Infantera': [],
#  '29 Batalln de Infantera': [],
#  'Estacin de Polica Aeropuerto Morelia (Polica Federal)': [],
#  'Unknown Police Area Command, Adamawa State': [],
#  'Direccin de Seguridad Pblica (Acua)': [],
#  '82 Division': [],
#  'Police Mobile Force Squadron 8': [],
#  'Police Mobile Force Squadron 9': [],
#  'Police Mobile Force Squadron 2': [],
#  'Police Mobile Force Squadron 3': [],
#  'Police Mobile Force Squadron 1': [],
#  'Police Mobile Force Squadron 6': [],
#  'Police Mobile Force Squadron 7': [],
#  'Police Mobile Force Squadron 4': ['Joint Task Force, Kano State',
#   'Naibawa Police Division',
#   'Rano Police Area Command'],
#  'Police Mobile Force Squadron 5': [],
#  'Subestacin de Polica Pijijiapan (Polica Federal)': [],
#  '69 Batalln de Infantera': [],
#  '13 Amphibious Brigade': [],
#  '35 Zona Militar': ['Operacin Guerrero Seguro'],
#  "A' Police Division (Plateau State)": [],
#  'Ohuhu Police Division': [],
#  'Idi-Ape Police Station': [],
#  'Operation Delta Safe': [],
#  '7 Guards Battalion': [],
#  'Goron Dutse Police Division': [],
#  '23 Batalln de Infantera': ['Operacin Conjunta Chihuahua'],
#  '89 Batalln de Infantera': ['Operativo Conjunto Culiacn/Navolato'],
#  'Kusada Police Division': [],
#  "D' Police Division (Benue State)": [],
#  'Rejiyer/Remo Police Division': [],
#  '10 Regimiento de Caballera Motorizado': [],
#  'Subestacin de Polica Santa Ana (Polica Federal)': [],
#  'Ibeno Police Division': [],
#  'Ajalli Police Division': [],
#  '41 Batalln de Infantera': [],
#  '401 Aircraft Maintenance Depot': [],
#  'Rivers State Police Command': [],
#  'Akukutoru Police Division': [],
#  'Estacin de Polica Aeropuerto Mrida (Polica Federal)': [],
#  'Unknown Police Area Command, Rivers State': [],
#  'Primera Comandancia Regional (Uruapan, Michoacn)': [],
#  'Subestacin de Polica Ceballos (Polica Federal)': [],
#  'Oyo State Police Command': [],
#  'Panisau Police Division': [],
#  'Coordinacin Estatal Guanajuato (Polica Federal)': [],
#  'Coordinacin Estatal Baja California Sur (Polica Federal)': [],
#  'Michika Police Division': [],
#  'Coordinacin Estatal Sonora (Polica Federal)': [],
#  'Presidencia Municipal de Acua': [],
#  '177 Guards Battalion': [],
#  '77 Batalln de Infantera': ['Operativo Semana Santa Segura 2015'],
#  '4 Batalln de Infantera': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  '192 Motorised Battalion': ['African Union/United Nations Hybrid operation in Darfur',
#   'Military Observer Group',
#   'Operation Lafiya Dole',
#   'Operation Zaman Lafiya',
#   'United Nations Mission in Liberia'],
#  'Estacin de Polica San Luis Potos (Polica Federal)': [],
#  'Dakatsalle Police Division': [],
#  'Sallari Police Division': [],
#  'Operacin Noreste': [],
#  'Oyo State Command (State Security Service)': [],
#  'Estacin de Polica Aeropuerto Veracruz (Polica Federal)': [],
#  'Nigerian Battalion 41 (UNAMID)': [],
#  'Kaduna State Police Command': [],
#  'Sabon Gari Police Division (Katsina State)': [],
#  'Joint Task Force, Operation Restore Hope': [],
#  'Unknown Police Area Command, Yobe State': [],
#  'Joint Task Force, Operation Pulo Shield, Sector 5': [],
#  'Joint Task Force, Operation Pulo Shield, Sector 4': [],
#  'Joint Task Force, Operation Pulo Shield, Sector 3': [],
#  'Joint Task Force, Operation Pulo Shield, Sector 2': [],
#  'Joint Task Force, Operation Pulo Shield, Sector 1': [],
#  'Kebbi State Command (State Security Service)': [],
#  'Estacin de Polica Teziutln (Polica Federal)': [],
#  'Primera Comandancia Regional (Lzaro Crdenas, Michoacn)': [],
#  '7 Division Garrison': ['Operation Lafiya Dole'],
#  'President of the Federal Republic of Nigeria': [],
#  '1 Division Garrison': [],
#  'Aba Central Police Station': [],
#  'Subestacin de Polica Jerez (Polica Federal)': [],
#  'Olu Obasanjo Police Division': [],
#  '14 Batalln de Infantera de Marina': [],
#  'Ifako Police Division': [],
#  '19 Zona Militar': [],
#  '13 Batalln de Infantera': [],
#  'Oji-River Area Police Command': [],
#  'Estacin de Polica Piedras Negras (Polica Federal)': [],
#  'Police Mobile Force Squadron 19': [],
#  'Direccin Regional de Averiguaciones Previas (Zitcuaro, Michoacn)': [],
#  'Joint Task Force, Operation Pulo Shield': [],
#  'Subestacin de Polica Monte Morelos (Polica Federal)': [],
#  'Subprocuradura Regional de Justicia de Zitcuaro (Michoacn)': [],
#  'Estacin de Polica Navojoa (Polica Federal)': [],
#  'Jigawa State Command (State Security Service)': [],
#  '46 Zona Militar': [],
#  'Estacin de Polica Palomares (Polica Federal)': [],
#  'Oko Police Division': [],
#  '17 Batalln de Infantera de Marina': [],
#  'Estacin de Polica Guadalajara (Polica Federal)': [],
#  'Estacin de Polica Ensenada (Polica Federal)': [],
#  'Estacin de Polica Culiacn (Polica Federal)': [],
#  'Ringim Police Division': [],
#  '33 Zona Militar': [],
#  'Oron Police Division': [],
#  '32 Batalln de Infantera de Marina': [],
#  'Ishasi Police Division': [],
#  'Nnewi Police Area Command': [],
#  'Madagali Police Division': [],
#  'Unknown Police Area Command, Abia State': [],
#  '87 Batalln de Infantera': ['Operacin Veracruz Seguro'],
#  '95 Batalln de Infantera': [],
#  'Secretara General (Polica Federal)': [],
#  "Area 'K' Police Area Command (Lagos State)": [],
#  '6 Batalln de Infantera de Marina': [],
#  'VIII Regin Militar': [],
#  'Coordinacin Estatal Morelos (Polica Federal)': [],
#  'Tarauni Police Division': [],
#  'Estacin de Polica Los Cabos (Polica Federal)': [],
#  '14 Base Area Militar': [],
#  'Bauchi State Command (State Security Service)': [],
#  'Plateau State Police Command': [],
#  '3 Armoured Division': ['Operation BOYONA', 'Operation Lafiya Dole'],
#  'Igando Police Division': [],
#  'Central Police Station (Nnewi, Anambra State)': [],
#  'Direccin General de Planes y Supervisin (Polica Federal)': [],
#  'Estacin de Polica Perote (Polica Federal)': [],
#  'Adani Police Area Command': [],
#  '96 Batalln de Infantera': ['Operacin Conjunta Chihuahua'],
#  '8 Zona Naval': [],
#  'Ika Police Division': [],
#  'Subprocuradura Regional de Justicia de Zamora (Michoacn)': [],
#  '74 Batalln de Infantera': ['Mando Especial de la Huasteca',
#   'Operacin Conjunta Nuevo Len  Tamaulipas'],
#  '9 Zona Naval': [],
#  'Ogidi Police Division': [],
#  'Estacin de Polica Aeropuerto Ciudad Jurez (Polica Federal)': [],
#  'Kogi State Command (State Security Service)': [],
#  'Nsukka Police Division': [],
#  'Armed Forces Council': [],
#  'Umuahia Police Area Command': [],
#  '86 Batalln de Infantera': [],
#  '93 Batalln de Infantera': [],
#  'Fiscala Regional Morelia (Michoacn)': [],
#  'Comisin Nacional de Seguridad': [],
#  'Estacin de Polica Saltillo (Polica Federal)': [],
#  'Direccin Regional de Control de Procesos (Lzaro Crdenas, Michoacn)': [],
#  'Estacin de Polica Mazatln (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Ciudad Obregn (Polica Federal)': [],
#  'Inland Town Police Division': [],
#  'State Security Service': ['Joint Task Force, Operation Restore Order I'],
#  'Maiha Police Division': [],
#  'Estacin de Polica Durango (Polica Federal)': [],
#  'Kwalli Police Division': [],
#  'Subestacin de Polica Pedricea (Polica Federal)': [],
#  '51 Batalln de Infantera': [],
#  'Subestacin de Polica Cosamaloapan (Polica Federal)': [],
#  'Unknown Police Division, Adamawa State': [],
#  "No Man's Land Police Division": [],
#  '7 Zona Naval': [],
#  'Estacin de Polica Aeropuerto Cancn (Polica Federal)': [],
#  'Osisioma Police Division': [],
#  'Coordinacin Estatal Hidalgo (Polica Federal)': [],
#  'Subprocuradura Regional de Justicia de Uruapan (Michoacn)': [],
#  '9 Brigade': ['Operation BOYONA'],
#  '4 Zona Naval': [],
#  'Estacin de Polica Uruapan (Polica Federal)': [],
#  'Estacin de Polica Huauchinango (Polica Federal)': [],
#  '12 Basea Area Militar': [],
#  '12 Batallon de Infantera de Marina': [],
#  '34 Batalln de Infantera': ['Operacin Conjunta Nuevo Len  Tamaulipas',
#   'Operacin Guerrero Seguro'],
#  'Estacin de Polica Matehuala (Polica Federal)': [],
#  'Polica Municipal de Tcpan de Galeana': [],
#  'Akwanga Police Division': [],
#  'Enugu State Police Command': [],
#  'Estacin Santa Rosalia (Polica Federal)': [],
#  'Criminal Intelligence Bureau (Abia State Police Command)': [],
#  'Operacin Conjunta Chihuahua': [],
#  'Subestacin de Polica Tecomn (Polica Federal)': [],
#  'Ondo State Police Command': [],
#  'State Criminal Investigation Department (Akwa Ibom State Police Command)': [],
#  '12 Batalln de Infantera de Marina': [],
#  '234 Special Operations Battalion': ['African Union Mission in the Sudan',
#   'Operation Zaman Lafiya'],
#  'Subestacin de Polica Costa Esmeralda (Polica Federal)': [],
#  'Estacin de Polica Tepatitln (Polica Federal)': [],
#  'Estacin de Polica Ciudad Jurez (Polica Federal)': [],
#  'Borno State Police Command': [],
#  '6 Zona Militar': ['Operacin Noreste'],
#  '1 Brigade': ['Nigerian Battalion 36 (UNMIL)',
#   'Operation Restore Peace',
#   'Special Task Force'],
#  '18 Zona Militar': [],
#  'Rantya Police Division': [],
#  'Estacin de Polica Cancn (Polica Federal)': [],
#  '2 Batalln de Infantera': ['Operacin Chihuahua'],
#  'Operacin Conjunta Nuevo Len  Tamaulipas': [],
#  'Etim Ekpo Police Division': [],
#  'Daura Police Division': [],
#  'Coordinacin de Restablecimiento del Orden Pblico (Polica Federal)': [],
#  'Ikot Ekpene Police Area Command (1)': [],
#  'Subestacin de Polica Libres (Polica Federal)': [],
#  'Direccin de Seguridad Pblica (Abasolo, Coahuila)': [],
#  '3 Zona Naval': [],
#  '46 Batalln de Infantera': [],
#  '5 Batalln de Infantera de Marina': [],
#  'Borno State Command (State Security Service)': [],
#  '19 Battalion': ['African Union/United Nations Hybrid operation in Darfur',
#   'Joint Task Force, Operation Pulo Shield, Sector 1'],
#  'Otolo Police Division': [],
#  'Estacin de Polica Hermosillo (Polica Federal)': [],
#  'Iseyin Police Station': [],
#  '2 Brigade Provost Company': [],
#  '71 Batalln de Infantera': [],
#  'Adamawa State Command (State Security Service)': [],
#  '22 Battalion': ['Military Observer Group', 'Operation BOYONA'],
#  'Estacin de Polica Tehuantepec (Polica Federal)': [],
#  'Estacin de Polica Ojuelos (Polica Federal)': [],
#  'Direccin General de Informacin (Polica Federal)': [],
#  'Hotoro Police Division': [],
#  'Edo State Command (State Security Service)': [],
#  'Oyo Police Area Command': [],
#  'Agentes del Ministerio Pblico Locales (Morelia, Michoacn)': [],
#  'Obehie Police Division': [],
#  'Sheka Police Division': [],
#  'XII Regin Militar': ['Operativo Conjunto Michoacn'],
#  '8 Batalln de Infantera de Marina': [],
#  'Subestacin de Polica Atotonilco (Polica Federal)': [],
#  'Operation BOYONA': [],
#  'Benue State Police Command': [],
#  'Ezeagu Police Division': [],
#  '4 Batalln de Infantera de Marina': [],
#  '7 Basea Area Militar': [],
#  '4 Regimiento Mecanizado': [],
#  '85 Batalln de Infantera': [],
#  "B' Police Division (Plateau State)": [],
#  'Fiscala Regional Uruapan (Michoacn)': [],
#  'Estacin de Polica Altamirano (Polica Federal)': [],
#  'X Regin Militar': [],
#  'Wudil Police Division': [],
#  'Direccin General de Fichas y Registro de Narcotrfico y Delitos Conexos (Polica Federal)': [],
#  'Afam Police Division': [],
#  'Estacin de Polica Puerto Vallarta (Polica Federal)': [],
#  'Cross River State Command (State Security Service)': [],
#  'Operacin Interinstitucional Culiacn-Navolato-Guamchil': [],
#  'Akpor Police Division': [],
#  'Polica Municipal de Leonardo Bravo': [],
#  "C' Police Division (Benue State)": [],
#  'Ikot Nakanda Police Division': [],
#  '25 Batalln de Infantera': [],
#  'United Nations Mission in Sierra Leone': [],
#  '27 Batalln de Infantera de Marina': [],
#  'Estacin de Polica Villahermosa (Polica Federal)': [],
#  '35 Batalln de Infantera': ['Operacin Conjunta Chihuahua'],
#  '33 Artillery Brigade': ['African Union Mission in the Sudan'],
#  'Taraba State Police Command': [],
#  'Mokola Police Division': [],
#  'Niger State Command (State Security Service)': [],
#  'Ondo State Command (State Security Service)': [],
#  'Ibesikpo Asutan Police Division': [],
#  'Direccin Regional de Control de Procesos (Morelia, Michoacn)': [],
#  '48 Batalln de Infantera': [],
#  'Unknown Police Area Command, Oyo State': [],
#  'Coordinacin General de Fiscalas Regionales (Michoacn)': [],
#  'Estacin de Polica Tijuana (Polica Federal)': [],
#  '11 Zona Militar': [],
#  'Estacin de Polica Apatzingn (Polica Federal)': [],
#  'Agentes del Ministerio Pblico Adscritos al Supremo Tribunal de Justicia (Morelia, Michoacn) ': [],
#  '1 Regin Naval': [],
#  '23 Batalln de Infantera de Marina': [],
#  'Ugwuaji Police Division': [],
#  'Bori Police Division': [],
#  'Divisin de Investigacin (Polica Federal)': [],
#  'Iyaganku Police Area Command': [],
#  'Estacin de Polica Tuxpan (Polica Federal)': [],
#  'Dobeli Police Station': [],
#  '72 Batalln de Infantera': [],
#  'Police Mobile Force Squadron 10': [],
#  'Police Mobile Force Squadron 11': [],
#  'Police Mobile Force Squadron 12': [],
#  'Police Mobile Force Squadron 14': [],
#  'Police Mobile Force Squadron 15': [],
#  'Police Mobile Force Squadron 16': [],
#  'Police Mobile Force Squadron 17': [],
#  'Police Mobile Force Squadron 18': [],
#  'Lagos State Command (State Security Service)': [],
#  'Rumorji Police Division': [],
#  'Taraba State Command (State Security Service)': [],
#  'Gombi Police Area Command': [],
#  'Gashua Police Division': [],
#  'Subestacin de Polica Santa Mara del Ro (Polica Federal)': [],
#  'Oko-Oba Police Division': [],
#  'Gwarzo Police Division': [],
#  'Subestacin de Polica Zacapu (Polica Federal)': [],
#  'Kibiya Police DIvision': [],
#  'Civilian Joint Task Force': [],
#  'Ilashe Police Division': [],
#  'Akwanga Police Area Command': [],
#  'Alagbado Police Division': [],
#  'Estado Mayor Presidencial': [],
#  'Isiokpo Police Station ': [],
#  'Joint Task Force, Operation Restore Order III': [],
#  'Song Police Division': [],
#  'Umuabor Police Division': [],
#  '27 Zona Militar': [],
#  '13 Compaa de Infantera no Encuadrada': [],
#  '14 Zona Militar': [],
#  'Ilemba Hausa Police Division': [],
#  'Isheri Police Division': [],
#  'Coordinacin Estatal Durango (Polica Federal)': [],
#  'Subestacin de Polica Ptzcuaro (Polica Federal)': [],
#  'Coordinacin Estatal Queretaro (Polica Federal)': [],
#  'Subestacin de Polica Santiago Papasquiaro (Polica Federal)': [],
#  '13 Basea Area Militar': [],
#  'Agodi Police Area Command': [],
#  'Estacin de Polica San Quintn (Polica Federal)': [],
#  '2 Regin Naval ': [],
#  "B' Police Division (Anambra State)": [],
#  'Estacin de Polica Aeropuerto San Luis Potos (Polica Federal)': [],
#  'Akodo Police Division': [],
#  'Estacin de Polica Aeropuerto Guadalajara (Polica Federal)': [],
#  '8 Zona Militar': [],
#  'Divisin de Inteligencia (Polica Federal)': [],
#  '102 Batalln de Infantera': [],
#  'Direccin General de Inteligencia Operativa Antidrogas (Polica Federal)': [],
#  'Estacin de Polica Campeche (Polica Federal)': [],
#  "D' Police Division (Uyo Itam, Akwa Ibom State)": [],
#  'Oluyole Police Station': [],
#  'Anaocha Police Division': [],
#  'Estacin de Polica Calpulalpan (Polica Federal)': [],
#  'Coordinacin Estatal Coahuila (Polica Federal)': [],
#  '9 Batalln de Infantera': [],
#  'Estacin de Polica Oaxaca (Polica Federal)': [],
#  'Independence Layout Police Division': [],
#  'Gowon Estate Police Division': [],
#  'Subestacin de Polica Magdalena de Kino (Polica Federal)': [],
#  '14 Zona Naval': [],
#  'Kwara State Command (State Security Service)': [],
#  'Estacin de Polica Ixmiquilpan (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Puebla (Polica Federal)': [],
#  'Unknown Police Division, Rivers State': [],
#  'Daura Police Area Command': [],
#  'Danmusa Police Division': [],
#  'Estacin de Polica Nogales (Polica Federal)': [],
#  'Estacin de Polica Zapopan (Polica Federal)': [],
#  'Subestacin de Polica Pinotepa Nacional (Polica Federal)': [],
#  'Isheri Oshun Police Division': [],
#  "Area 'H' Police Area Command (Lagos State)": [],
#  'Central Police Station (Awka, Anambra State)': [],
#  'Subestacin de Polica Melaque (Polica Federal)': [],
#  'Coordinacin Regional Sureste (Polica Federal)': [],
#  'Estacin de Polica San Andres Tuxtla (Polica Federal)': [],
#  'Direccin Regional de Averiguaciones Previas (Apatzingn, Michoacn)': [],
#  'Jimeta Police Station': [],
#  'Nasarawa State Police Command': [],
#  '435 Base Support Group': [],
#  'Estacin de Polica Aeropuerto Campeche (Polica Federal)': [],
#  'Estacin de Polica Acapulco (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Mazatln (Polica Federal)': [],
#  'Oturkpo Police Area Command': [],
#  'Zone 4 Police Command': [],
#  '130 Battalion': ['Joint Task Force, Operation Pulo Shield',
#   'Joint Task Force, Operation Pulo Shield, Sector 2'],
#  'Polica Municipal de Chilpancingo de los Bravo': [],
#  'Musawa Police Division': [],
#  'Subestacin de Polica Cintalapa (Polica Federal)': [],
#  '8 Brigada de Infantera de Marina': [],
#  'Makurdi Police Area Command': [],
#  'Polica Municipal de Petatln': [],
#  'United Nations Organization Stabilization Mission in the Democratic Republic of the Congo': [],
#  'Subprocuradura Regional de Justicia de Morelia (Michoacn)': [],
#  '21 Zona Militar': ['Operativo Conjunto Michoacn'],
#  'State Criminal Investigation Department (Anambra State Police Command)': [],
#  'Seme Police Division': [],
#  'Estacin de Polica Aeropuerto Guaymas (Polica Federal)': [],
#  'Kaduna State Command (State Security Service)': [],
#  'Police Mobile Force Squadron 29': [],
#  'Police Mobile Force Squadron 28': [],
#  'Police Mobile Force Squadron 25': [],
#  'Police Mobile Force Squadron 24': [],
#  'Police Mobile Force Squadron 27': ['Special Task Force'],
#  'Police Mobile Force Squadron 26': [],
#  'Police Mobile Force Squadron 21': [],
#  'Police Mobile Force Squadron 20': [],
#  'Police Mobile Force Squadron 23': [],
#  'Police Mobile Force Squadron 22': [],
#  'Isiokpo Police Division': [],
#  'Galadima Police Division': [],
#  'Jigawa State Police Command': [],
#  '1 Zona Naval': [],
#  '53 Batalln de Infantera': [],
#  '34 Zona Militar': [],
#  '3 Basea Area Militar': [],
#  'Divisin de Fuerzas Federales (Polica Federal)': [],
#  'Nnobi Police Division': [],
#  'Umuopara Police Division': [],
#  '14 Batalln de Infantera': [],
#  '24 Batalln de Infantera': [],
#  '65 Batalln de Infantera': [],
#  'Nigerian Battalion 14 (UNIMIL)': [],
#  'Unknown Police Division, Katsina State': [],
#  'Estacin de Polica Tlaxcala (Polica Federal)': [],
#  '36 Batalln de Infantera': [],
#  'Coordinacin Regional Centro (Polica Federal)': [],
#  'Umuchu Police Division': [],
#  'Morogbo Police Division': [],
#  'Fiscala Regional Lzaro Crdenas (Michoacn)': [],
#  '16 Basea Area Militar': [],
#  'Estacin de Polica Chalco (Polica Federal)': [],
#  '174 Battalion': ['African Union Mission in the Sudan',
#   'African Union/United Nations Hybrid operation in Darfur',
#   'Multinational Joint Task Force',
#   'Operation BOYONA',
#   'United Nations Mission in Liberia'],
#  'Subestacin de Polica Huajuapan (Polica Federal)': [],
#  'Unknown Brigade, 81 Division': [],
#  'Sabon Gari Police Division (Kano State)': [],
#  'Subestacin de Polica Tlapa de Comonfort (Polica Federal)': [],
#  'Tudun Wada Police Division (Kano State)': [],
#  'Enugu Ezike Police Division': [],
#  '14 Brigade': [],
#  '80 Batalln de Infantera': [],
#  'Edo State Police Command': [],
#  '33 Batalln de Infantera': [],
#  'Subestacin de Polica La Cuchilla (Polica Federal)': [],
#  '3 Regin Naval ': [],
#  'Estacin de Polica Champotn (Polica Federal)': [],
#  '26 Batalln de Infantera': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Primera Comandancia Regional (Zitcuaro, Michoacn)': [],
#  'Subestacin de Polica Tizimn (Polica Federal)': [],
#  '213 Battalion': ['Operation Zaman Lafiya'],
#  'Estacin de Polica Autln de Navarro (Polica Federal)': [],
#  'Unknown Brigade, 82 Division': [],
#  'Direccin General de Prevencin de Operaciones con Recursos de Procedencia Ilcita (Polica Federal)': [],
#  '5 Compaa de Infantera no Encuadrada': [],
#  '2 Amphibious Brigade': [],
#  'Niger State Police Command': [],
#  '31 Batalln de Infantera': ['Operacin Conjunta Nuevo Len  Tamaulipas'],
#  'Gombe State Command (State Security Service)': [],
#  'Subestacin de Polica Pirmides (Polica Federal)': [],
#  'Subestacin de Polica Acaponeta (Polica Federal)': [],
#  'Bunkure Police Division': [],
#  'Coordinacin Estatal San Luis Potos (Polica Federal)': [],
#  '105 Batalln de Infantera': [],
#  '37 Zona Militar': [],
#  'Akwa Ibom State Police Command': [],
#  'Direccin General de Operacin Tcnica Antidrogas (Polica Federal)': [],
#  'Daura Central Police Station': [],
#  'State Criminal Investigation Department (Abia State Police Commmand)': [],
#  'Nigerian Battalion 36 (UNMIL)': [],
#  'Charanchi Police Division': [],
#  'Coordinacin Estatal Tlaxcala (Polica Federal)': [],
#  'Coordinacin Estatal Chiapas (Polica Federal)': [],
#  '10 Batalln de Infantera de Marina': [],
#  'Estacin de Polica Zacatecas (Polica Federal)': [],
#  'Estacin de Polica Aeropuerto Internacional Los Cabos (Polica Federal)': [],
#  'Damagum Police Division': [],
#  'Kpor Police Division': [],
#  'Coordinacin Estatal Michoacn (Polica Federal)': [],
#  'Udung Uko Police Division': [],
#  'Divisin Cientfica (Polica Federal)': [],
#  'Coordinacin de Operaciones Especiales (Polica Federal)': [],
#  ...}

# %%
dot = vg.Graph()
dot.engine = 'dot'
dot.attr('node', shape='circle', style = "filled", fillcolor = "red", height = "4")

def areagraph(area):
    alreadyedges = list()
    area = str(area)
    dot.node(area)
    dot.attr('node', shape='oval', style = "filled", fillcolor = "white", height = "0.02")
    if area not in resultpeople1.keys():
        print("This is not a valid entry. Here are valid entries.")
        return (list(set(resultpeople1.keys())))
    for j in range(len(resultpeople1[area])):
        person = resultpeople1[area][j]
        if (str(person), str(area)) not in alreadyedges:
            alreadyedges.append((str(person), str(area)))
            dot.edge(str(person), str(area), color = "red")
        personarea = resultpeople2[person]
        for r in range(len(personarea)):
            personarea1 = personarea[r]
            if (str(personarea1), str(person)) not in alreadyedges and (str(person), str(personarea1)) not in alreadyedges:
                alreadyedges.append((str(person), str(personarea1)))
                dot.edge(str(person), str(personarea1), color = "purple")
            if personarea1 in locations:
                location = resultlocation[personarea1]
                if len(location) == 0:
                    location = "No location given in data."
                    if (str(personarea1), str(location)) not in alreadyedges:
                        alreadyedges.append((str(personarea1), str(location)))
                        dot.edge(str(personarea1), str(location), color = "blue")
                else:
                    location = location[0]
                    if (str(personarea1), str(location)) not in alreadyedges:
                        alreadyedges.append((str(personarea1), str(location)))
                        dot.edge(str(personarea1), str(location), color = "blue", headlabel = "Location:")
            else:
                location = "No location given in data."
                if (str(personarea1), str(location)) not in alreadyedges:
                    alreadyedges.append((str(personarea1), str(location)))
                    dot.edge(str(personarea1), str(location), color = "blue")
        if area in keysorg:
            member = result[area]
            if len(member) == 0:
                member = ["No information about memberships."]
        else:
            member = ["No information about memberships."]
        if area in resultdate:
            dt = resultdate[area]
            if len(dt) == 0:
                dt3 = "No Date Given"
            else:
                dt1 = dt[len(dt)-1]
                dt2 = datetime.date(dt1.year, dt1.month, dt1.day)
                dt3 = str(dt2.strftime('%B %d, %Y'))
        else:
            dt3 = "N/A"
        for r in range(len(member)):
            if (str(area), str(member[r])) not in alreadyedges:
                alreadyedges.append((str(area), str(member[r])))
                dot.edge(str(area), str(member[r]), color = "green", headlabel = "Last Confirmed: " + dt3 + ".")
        if area in locations:
            location = resultlocation[area]
            if len(location) == 0:
                location = "No location given in data."
                if (str(area), str(location)) not in alreadyedges:
                    alreadyedges.append((str(area), str(location)))
                    dot.edge(str(area), str(location), color = "blue")
            else:
                location = location[0]
                if (str(area), str(location)) not in alreadyedges:
                    alreadyedges.append((str(area), str(location)))
                    dot.edge(str(area), str(location), color = "blue", headlabel = "Location:")
        else:
                location = "No location given in data."
                if (str(area), str(location)) not in alreadyedges:
                    alreadyedges.append((str(area), str(location)))
                    dot.edge(str(area), str(location), color = "blue")
    return dot
areagraph("1 Zona Militar")
dot.render('Graph1.jpg', view=True)
'Graph1.jpg'
# Out:
# 'Graph1.jpg'

# %%
dot.source
# Out:
# 'graph {\n\tnode [fillcolor=red height=4 shape=circle style=filled]\n\t"1 Zona Militar"\n\tnode [fillcolor=white height=0.02 shape=oval style=filled]\n\t\t"Alfonso Duarte Mgica" -- "1 Zona Militar" [color=red]\n\t\t"Alfonso Duarte Mgica" -- "II Regin Militar" [color=purple]\n\t\t"II Regin Militar" -- "Baja California" [color=blue headlabel="Location:"]\n\t\t"Alfonso Duarte Mgica" -- "III Regin Militar" [color=purple]\n\t\t"III Regin Militar" -- Chihuahua [color=blue headlabel="Location:"]\n\t\t"Alfonso Duarte Mgica" -- "2 Zona Militar" [color=purple]\n\t\t"2 Zona Militar" -- "Baja California" [color=blue headlabel="Location:"]\n\t\t"1 Zona Militar" -- "Ciudad de Mxico" [color=blue headlabel="Location:"]\n\t\t"1 Zona Militar" -- "No information about memberships." [color=green headlabel="Last Confirmed: No Date Given."]\n\t\t"Carlos Garca Lpez" -- "1 Zona Militar" [color=red]\n\t\t"Carlos Garca Lpez" -- "24 Zona Militar" [color=purple]\n\t\t"24 Zona Militar" -- Morelos [color=blue headlabel="Location:"]\n\t\t"Germn Redondo Azuara" -- "1 Zona Militar" [color=red]\n\t\t"Germn Redondo Azuara" -- "18 Zona Militar" [color=purple]\n\t\t"18 Zona Militar" -- Hidalgo [color=blue headlabel="Location:"]\n\t\t"Germn Redondo Azuara" -- "2 Zona Militar" [color=purple]\n\t\t"Gilberto Garca Garca" -- "1 Zona Militar" [color=red]\n\t\t"Gustavo Nieto Navarro" -- "1 Zona Militar" [color=red]\n\t\t"Gustavo Nieto Navarro" -- "X Regin Militar" [color=purple]\n\t\t"X Regin Militar" -- Campeche [color=blue headlabel="Location:"]\n\t\t"J Samuel Toribio Surez" -- "1 Zona Militar" [color=red]\n\t\t"Jos Luis Gutirrez Velarde" -- "1 Zona Militar" [color=red]\n\t\t"Jos Ricardo Brcena Rosiles" -- "1 Zona Militar" [color=red]\n\t\t"Noe Antonio Ordoez Herran" -- "1 Zona Militar" [color=red]\n}'

# %%
resultpeople2[person]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-9df594eab9b7> in <module>()
# ----> 1 resultpeople2[person]
#
# NameError: name 'person' is not defined
